# %%
# python
import json
import time
import pickle
import re, string
import os
from os import path, listdir
from pathlib import Path
from os.path import isfile, join
from types import new_class
from typing import List
from lxml import etree 
from contextlib import ExitStack
import sklearn.feature_extraction.text
from nltk.tokenize import PunktSentenceTokenizer, RegexpTokenizer, TreebankWordTokenizer
from sklearn.feature_extraction.text import CountVectorizer, HashingVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.spatial.distance import cosine
from sklearn.metrics.pairwise import cosine_similarity

# Among the larger bills is samples/congress/116/BILLS-116s1790enr.xml (~ 10MB)

PATH_116_USLM = '/usr/local/share/xcential/public/data/116/uslm'
PATH_117_USLM = '/usr/local/share/xcential/public/data/117/uslm'
PATH_116_USLM_TRAIN = 'samples/congress/116/train'
PATH_116_TEXT = 'samples/congress/116/txt'

BILLS_SAMPLE = [f'BILLS-116hr{number}ih.xml' for number in range(100, 300)]
BIG_BILLS = ['BILLS-116s1790enr.xml', 'BILLS-116hjres31enr.xml']
BIG_BILLS_PATHS = [path.join(PATH_116_USLM, bill) for bill in (BIG_BILLS + BILLS_SAMPLE)]

SAMPLE_BILL_PATHS_TRAIN = [join(PATH_116_USLM_TRAIN, f) for f in listdir(PATH_116_USLM) if isfile(join(PATH_116_USLM_TRAIN, f))]
SAMPLE_BILL_PATHS = [join(PATH_117_USLM, f) for f in listdir(PATH_117_USLM) if isfile(join(PATH_117_USLM, f))]


NAMESPACES = {'uslm': 'http://xml.house.gov/schemas/uslm/1.0'}


def get_filepaths(dirpath: str, reMatch = r'.xml$') -> List[str]:
    return [join(dirpath, f) for f in listdir(dirpath) if (len(re.findall(reMatch, f)) > 0) and isfile(join(dirpath, f))]

def getEnum(section) -> str:
  enumpath = section.xpath('enum')  
  if len(enumpath) > 0:
    return enumpath[0].text
  return ''

def getHeader(section) -> str:
  headerpath = section.xpath('header')  
  if len(headerpath) > 0:
    return headerpath[0].text
  return ''

def text_to_vect(txt: str , ngram_size: int = 4):
    """
    Gets ngrams from text
    """
    # See https://stackoverflow.com/a/32128803/628748
    tokenizer = PunktSentenceTokenizer()
    sentences = tokenizer.tokenize(txt)
    #vect = sklearn.feature_extraction.text.CountVectorizer(ngram_range=(ngram_size,ngram_size),
    #    tokenizer=TreebankWordTokenizer().tokenize, lowercase=True)
    vect = sklearn.feature_extraction.text.CountVectorizer(ngram_range=(ngram_size,ngram_size),
        tokenizer=RegexpTokenizer(r"\w+").tokenize, lowercase=True)
    vect.fit(sentences)
    # ngrams = vect.get_feature_names_out()
    # print('{1}-grams: {0}'.format(ngrams, ngram_size))
    #print(vect.vocabulary_)
    return vect # list of text documents

def xml_to_sections(xml_path: str):
    """
    Parses the xml file into sections 
    """
    try:
        billTree = etree.parse(xml_path)
    except:
        raise Exception('Could not parse bill')
    sections = billTree.xpath('//uslm:section', namespaces=NAMESPACES)
    if len(sections) == 0:
        print('No sections found')
        return []
    return [{
            'section_number': getEnum(section) ,
            'section_header':  getHeader(section),
            'section_text': etree.tostring(section, method="text", encoding="unicode"),
            'section_xml': etree.tostring(section, method="xml", encoding="unicode")
        } if (section.xpath('header') and len(section.xpath('header')) > 0  and section.xpath('enum') and len(section.xpath('enum'))>0) else
        {
            'section_number': '',
            'section_header': '', 
            'section_text': etree.tostring(section, method="text", encoding="unicode"),
            'section_xml': etree.tostring(section, method="xml", encoding="unicode")
        } 
        for section in sections ]

def xml_to_text(xml_path: str, level: str = 'section', separator: str = '\n*****\n') -> str:
    """
    Parses the xml file and returns the text of the body element, if any
    """
    try:
        billTree = etree.parse(xml_path)
    except:
        raise Exception('Could not parse bill')
    #return etree.tostring(billTree, method="text", encoding="unicode")
    # Use 'body' for level to get the whole body element
    sections = billTree.xpath('//uslm:'+level, namespaces=NAMESPACES)
    if len(sections) == 0:
        print('No sections found')
        return '' 
    return separator.join([etree.tostring(section, method="text", encoding="unicode") for section in sections])

def xml_to_vect(xml_paths: List[str], ngram_size: int = 4):
    """
    Parses the xml file and returns the text of the body element, if any
    """
    total_str = '\n'.join([xml_to_text(xml_path) for xml_path in xml_paths])
    return text_to_vect(total_str, ngram_size=ngram_size)

    # to get the vocab dict: vect.vocabulary_

def combine_vocabs(vocabs: List[CountVectorizer]):
    """
    Combines one or more vocabs into one
    """
    vocab_keys = list(set([list(v.vocabulary_.keys()) for v in vocabs]))
    vocab = {vocab_key: str(i) for i, vocab_key in enumerate(vocab_keys)}
    return vocab

def get_combined_vocabs(xml_paths: List[str] = SAMPLE_BILL_PATHS, ngram_size: int = 4):
    """
    Gets the combined vocabulary of all the xml files
    """
    return xml_to_vect(xml_paths, ngram_size=ngram_size)

def getSampleText(level = 'body'):
    return xml_to_text(BIG_BILLS_PATHS[0])

def transform_text(text: str, vocab: dict, ngram_size: int = 4):
    """
    Transforms text into a vector using the vocab
    """
    return CountVectorizer(vocabulary=vocab).fit_transform([text])

def train_count_vectorizer(train_data: List[str], ngram_size: int = 4):
    """
    Trains a count vectorizer on the training data
    """
    vectorizer = CountVectorizer(ngram_range=(ngram_size,ngram_size), preprocessor=xml_to_text, tokenizer=RegexpTokenizer(r"\w+").tokenize, lowercase=True)
    with ExitStack() as stack:
        files = [
            stack.enter_context(open(filename))
            for filename in train_data 
        ]
        X = vectorizer.fit_transform(files)
    return vectorizer, X 

def train_hashing_vectorizer(train_data: List[str], ngram_size: int = 4):
    """
    Trains a hashing vectorizer on the training data
    """
    vectorizer = HashingVectorizer(ngram_range=(ngram_size,ngram_size), preprocessor=xml_to_text, tokenizer=RegexpTokenizer(r"\w+").tokenize, lowercase=True)
    with ExitStack() as stack:
        files = [
            stack.enter_context(open(filename))
            for filename in train_data 
        ]
        X = vectorizer.fit_transform(files)
    return vectorizer, X

def test_hashing_vectorizer(vectorizer: HashingVectorizer, test_data: List[str]):
    return vectorizer.transform(test_data)

def xml_samples_to_text(dirpath: str, level: str = 'section', separator: str = '\n*****\n'):
    """
    Converts xml files in a directory to txt files
    """
    xfiles = get_filepaths(dirpath)
    for xfile in xfiles:
        with open(xfile.replace('.xml', f'-{level}s.txt'), 'w') as f:
            f.write(xml_to_text(xfile, level=level, separator=separator))

# TODO: Add a function to parse the bill (text) into paragraphs 

# TODO: create a streaming hash vectorizer. See 
# https://scikit-learn.org/stable/auto_examples/applications/plot_out_of_core_classification.html#sphx-glr-auto-examples-applications-plot-out-of-core-classification-py

# %% [markdown]
# ### Utility function for Text Cleaning

# %%
#clean text 
def text_cleaning(text):
    text = str(text).lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    return text

# %% [markdown]
# # Data Loading & Data Pre-processing

# %%
#xml document and section level parsing

#record training time for both vectorizer
start = time.time()


doc_corpus_data=[]
section_corpus_data = []

#get all xml files from data directory for parsing
bill_files = [f for f in os.listdir(PATH_117_USLM) if f.endswith('.xml')]

#iterate over all bill files
for i in range(0, len(bill_files)):
    
    #indexing bill document file
    bill_doc_file = bill_files[i]
    
    #parse xml into sections
    secs = xml_to_sections(os.path.join(PATH_117_USLM, bill_doc_file))
    
    #check  of sections should be 1 or more than 1
    if(len(secs)>0):  
        
        #intialize string variable for document content
        doc_content = ""
        
        #iterate over all parse sections text of bill doc file
        for s_number, section in enumerate(secs):  
            
            #text cleaning applied on each section text
            sec_text = text_cleaning(section['section_text'])
            
            #concatenate section text to doc content 
            doc_content = doc_content + sec_text + " "
            
             #for now sentence id is sentence number in document
            section_corpus_data.append([Path(bill_doc_file).stem[:], s_number, sec_text ])

        doc_corpus_data.append([Path(bill_doc_file).stem[:], doc_content])
    

#get only whole document content from doc_corpus_data list
only_doc_data = [row[1] for row in doc_corpus_data]

#get only section content from section_corpus_data list
only_section_data = [row[2] for row in section_corpus_data]


#get length of only_doc_data list
print(len(only_doc_data))

#get length of only_section_data list
print(len(only_section_data))

done = time.time()
elapsed = done - start
print('Time took in ETL with {} xml data files is {}'.format(len(only_doc_data), elapsed))
# Out:
# No sections found
# No sections found
# 12805
# 81642
# Time took in ETL with 12805 xml data files is 105.39807391166687

# %% [markdown]
# # NLP Modeling

# %% [markdown]
# ## Model Training

# %%
#record training time for both vectorizer
start = time.time()


# Vectorizer to convert a collection of raw documents to a matrix 
doc_tfidf_vectorizer = TfidfVectorizer(ngram_range=(4,4), tokenizer=RegexpTokenizer(r"\w+").tokenize, lowercase=True)
#Fit tfidf vectorize instance on document level corpus
tv_doc_matrix = doc_tfidf_vectorizer.fit_transform(only_doc_data)

# Vectorizer to convert a collection of sections to a matrix 
sec_tfidf_vectorizer = TfidfVectorizer(ngram_range=(4,4), tokenizer=RegexpTokenizer(r"\w+").tokenize, lowercase=True)
#Fit tfidf vectorize instance on section level corpus
tv_section_matrix = sec_tfidf_vectorizer.fit_transform(only_section_data)


done = time.time()
elapsed = done - start
print("Time took in training of both vectorizer(s) ", elapsed)
# Out:
# Time took in training of both vectorizer(s)  185.00698709487915

# %% [markdown]
# ## Model Saving & Loading

# %%
# save tfidf vectorize instance for only_doc_data
pickle.dump(doc_tfidf_vectorizer, open("doc_tfidf_vectorizer.pickle", "wb"))
# load tfidf vectorize instance for only_doc_data
doc_tfidf_vectorizer = pickle.load(open("doc_tfidf_vectorizer.pickle", "rb"))

#save tfidf vectorize instance for only_section_data
pickle.dump(sec_tfidf_vectorizer, open("sec_tfidf_vectorizer.pickle", "wb"))
# load tfidf vectorize instance for only_section_data
sec_tfidf_vectorizer = pickle.load(open("sec_tfidf_vectorizer.pickle", "rb"))

# %% [markdown]
# ## Get Document and Sections Text from XML File

# %%
#et document and section text from xml file for testing purpose 
def get_document_and_section_from_xml_file(file_path):
    
    #create empty t_section_data list
    t_section_data=[] 
    
    #get sections fron xml file
    t_secs = xml_to_sections(file_path)
    
    #check if length of section is more than 0  
    if(len(t_secs)>0): 
        
            #intialize string variable for document content
            t_doc_content = ""

            #iterate over all parse sections text of bill doc file
            for s_number, section in enumerate(t_secs):  

                #text cleaning applied on each section text
                sec_text = text_cleaning(section['section_text'])

                #concatenate section text to doc content 
                t_doc_content = t_doc_content + sec_text + " "

                 #for now sentence id is sentence number in document
                t_section_data.append(sec_text)

    return t_doc_content, t_section_data

# %% [markdown]
# ## Calculate Cosine Similarity

# %%
#choose document A file name & document B file name 
A_doc_name = 'BILLS-117hr2547ih'
B_doc_name = 'BILLS-117hr2547rfs'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

print("A section doc[6]:")
print(A_section_doc[6])

print("A number of sections:")
print(len(A_section_doc))
# Out:
# A section doc[6]:
# sec  enhanced protection against debt collector harassment of servicemembersa communication in connection with debt collection—section  of the fair debt collection practices act  usc  is amended by adding at the end the following“e communications concerning servicemember debts—“ definition—in this subsection the term ‘covered member’ means—“a a covered member or a dependent as defined in section  of title  united states code and“bi an individual who was separated discharged or released from duty described in such section  but only during the  period beginning on the date of separation discharge or release or“ii a person with respect to an individual described in clause i described in subparagraph a d e or i of section  of title  united states code“ prohibitions—a debt collector may not in connection with the collection of any debt of a covered member—“a threaten to have the covered member reduced in rank“b threaten to have the covered member’s security clearance revoked or“c threaten to have the covered member prosecuted under chapter  of title  united states code the uniform code of military justice”b unfair practices—section  of the fair debt collection practices act  usc  is amended by adding at the end the following“ the representation to any covered member as defined under section  that failure to cooperate with a debt collector will result in—“a a reduction in rank of the covered member“b a revocation of the covered member’s security clearance or“c prosecution under chapter  of title  united states code the uniform code of military justice”
# A number of sections:
# 29

# %% [markdown]
# ## Transform Document A & B into vectorized space to perform cosine similarity

# %%
def document_tfidf_vectorized_transformation(document, doc_tfidf_vectorizer):
    
    doc_vectorized = doc_tfidf_vectorizer.transform([document])
    return doc_vectorized

def section_doc_tfidf_vectorized_transformation(section_doc, sec_tfidf_vectorizer):
    
    section_doc_vectorized = sec_tfidf_vectorizer.transform(section_doc)
    return section_doc_vectorized

# %%
#record training time for both vectorizer
start = time.time()

#transform document A content and document B content
A_doc_vectorized = document_tfidf_vectorized_transformation(A_doc, doc_tfidf_vectorizer)
B_doc_vectorized = document_tfidf_vectorized_transformation(B_doc, doc_tfidf_vectorizer)

#transform document A section content and  document B section content
A_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(A_section_doc, sec_tfidf_vectorizer)
B_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(B_section_doc, sec_tfidf_vectorizer)

#show form of vectorized doc
print("A_section_doc_vectorized (a sparse matrix; see https://stackoverflow.com/q/15115765/628748 and https://stackoverflow.com/a/49738773/628748)")
print(A_section_doc_vectorized)

print("Length of A_section_doc_vectorized")
print(len(A_section_doc_vectorized.todense()))

done = time.time()
elapsed = done - start
print("Time took in vectorizing both documents ", elapsed)
# Out:
# A_section_doc_vectorized (a sparse matrix; see https://stackoverflow.com/q/15115765/628748 and https://stackoverflow.com/a/49738773/628748)
#   (0, 5565248)	0.08121005883378808
#   (0, 5564171)	0.08121005883378808
#   (0, 5559976)	0.08121005883378808
#   (0, 5538452)	0.08121005883378808
#   (0, 5391527)	0.08121005883378808
#   (0, 5373082)	0.08121005883378808
#   (0, 5348028)	0.07287241830948726
#   (0, 5257695)	0.08121005883378808
#   (0, 5216068)	0.08121005883378808
#   (0, 5216067)	0.08121005883378808
#   (0, 5216048)	0.08121005883378808
#   (0, 5216047)	0.08121005883378808
#   (0, 5216015)	0.08121005883378808
#   (0, 5215991)	0.08121005883378808
#   (0, 5215927)	0.08121005883378808
#   (0, 5215910)	0.08121005883378808
#   (0, 5214041)	0.04433951528035008
#   (0, 5213692)	0.05549940085775523
#   (0, 5213688)	0.0466655543936124
#   (0, 5159123)	0.03769340254983612
#   (0, 5158961)	0.04473872310657974
#   (0, 5102390)	0.03729186256515947
#   (0, 5061960)	0.07287241830948726
#   (0, 4948039)	0.05803248811455758
#   (0, 4903499)	0.08121005883378808
#   :	:
#   (28, 5159810)	0.2536967440169108
#   (28, 4919151)	0.16235738345127032
#   (28, 4918919)	0.11214743035655018
#   (28, 4867904)	0.14632908638781447
#   (28, 4828609)	0.20348428759666023
#   (28, 4734751)	0.2057532226118277
#   (28, 4417215)	0.196252981503242
#   (28, 4253656)	0.2866893152129677
#   (28, 3354343)	0.1835119068642623
#   (28, 3150926)	0.11766648362795919
#   (28, 2805503)	0.20259095943291613
#   (28, 2633308)	0.2046015075550831
#   (28, 1700552)	0.101270669074161
#   (28, 1640335)	0.304663985452448
#   (28, 1638757)	0.18581376552080117
#   (28, 1421715)	0.11634302802440835
#   (28, 1419330)	0.30526086823785853
#   (28, 1417801)	0.20213323125794344
#   (28, 1416320)	0.11221544200388625
#   (28, 1010476)	0.21829675628243309
#   (28, 552240)	0.20990242577294704
#   (28, 322204)	0.1516909028480122
#   (28, 251468)	0.09158715462230417
#   (28, 170024)	0.25037540009274195
#   (28, 159296)	0.23842039529905157
# Length of A_section_doc_vectorized
# 29
# Time took in vectorizing both documents  0.4040391445159912

# %%
def cosine_pairwise_sim(a_vectorized, b_vectorized):
    
    #record time for computing similarity 
    start = time.time()

    sim_score =  cosine_similarity(a_vectorized, b_vectorized)

    done = time.time()
    elapsed = done - start
    return elapsed, sim_score

# %% [markdown]
# ## Measure Document Similarity Score of any Document A to any Document B

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)

print("elapsed: " + str(elapsed1))
print(doc_sim_score)
# Out:
# elapsed 1: 0.014885902404785156
# [[0.8490097]]
# elapsed 2: 0.014529943466186523
# [[0.8490097]]

# %% [markdown]
# ## Measure Pairwise similarity between Sections of Document A & Sections of Document B

# %%
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

# %%
print(elapsed)
print(sec_doc_sim_score)
# Out:
# 0.01469278335571289
# [[0.71088467 0.03478385 0.         ... 0.         0.00418193 0.        ]
#  [0.02527629 1.         0.         ... 0.         0.23520597 0.        ]
#  [0.01527173 0.         0.84355816 ... 0.         0.         0.05656838]
#  ...
#  [0.04155805 0.26936992 0.         ... 0.         0.20619126 0.        ]
#  [0.01467514 0.         0.00294065 ... 0.         0.         0.        ]
#  [0.         0.         0.         ... 0.55972105 0.         0.05080109]]

# %% [markdown]
# ## Rendering results of similarity b/w Document A & Document B and their Sections

# %%
def create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score):
    
    #create result list
    res_list = []

    #create empty list
    temp=[]
    temp.append("ORIGINAL DOCUMENT ID: " + A_doc_name)
    temp.append("MATCHED DOCUMENT ID: " + B_doc_name)
    temp.append("DOCUMENT SIMILARITY SCORE: " + str(doc_sim_score[0][0]))

    #iterate over sec_doc_sim_score list 
    for i, section_score_list in enumerate(sec_doc_sim_score):
        
        #add original document sentence id number
        temp.append("ORIGINAL SENTENCE ID: " + str(i+1))
           
        #sort similarity score of sections list
        section_score_list = list(enumerate(section_score_list))
        sorted_section_score_list = sorted(section_score_list, key=lambda x: x[1], reverse=True)
        
        #iterate over section level score only 
        for j, sim_score in sorted_section_score_list:
            temp.append({"MATCHED DOCUMENT ID":  B_doc_name, "MATCHED SENTENCE ID": j+1 , "SENTENCE SIMILARITY SCORE":  sim_score})

    res_list.append(temp)
        
    #return pretty json
    r = json.dumps(res_list)
    parsed = json.loads(r)
    return json.dumps(parsed, indent=5)

# %%
#put document A file name & document B file name
#A_doc_name = 'BILLS-117hr200ih'
#B_doc_name = 'BILLS-117hr201ih'

#get json response of newly computed similarity score of document A and document B
response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr2547ih",
#           "MATCHED DOCUMENT ID: BILLS-117hr2547rfs",
#           "DOCUMENT SIMILARITY SCORE: 0.8508737724037765",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.7117384009449566
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 19,
#                "SENTENCE SIMILARITY SCORE": 0.10299852574797382
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.1017117632842342
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 25,
#                "SENTENCE SIMILARITY SCORE": 0.08183411472716967
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.07925751995647415
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.05868961449188674
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 27,
#                "SENTENCE SIMILARITY SCORE": 0.05639935885319547
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 33,
#                "SENTENCE SIMILARITY SCORE": 0.05319169406596124
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.05173324649292921
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 26,
#                "SENTENCE SIMILARITY SCORE": 0.043602341590044766
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 34,
#                "SENTENCE SIMILARITY SCORE": 0.03761724958725887
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 20,
#                "SENTENCE SIMILARITY SCORE": 0.03651040158431493
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.03382366017579655
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 23,
#                "SENTENCE SIMILARITY SCORE": 0.03290248270989795
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.03143502512474436
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.03097688208230595
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.030480141781640192
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.03042712520308752
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.028589442968406438
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.02255395163337757
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 28,
#                "SENTENCE SIMILARITY SCORE": 0.01972085759797894
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 24,
#                "SENTENCE SIMILARITY SCORE": 0.01898387349721736
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 22,
#                "SENTENCE SIMILARITY SCORE": 0.013208658154321162
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 21,
#                "SENTENCE SIMILARITY SCORE": 0.01307634142316798
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.012563202405968886
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 39,
#                "SENTENCE SIMILARITY SCORE": 0.009696411397493596
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.005754643117211416
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.005685803556543568
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 42,
#                "SENTENCE SIMILARITY SCORE": 0.004225440835510458
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 29,
#                "SENTENCE SIMILARITY SCORE": 0.0036528813838718373
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 30,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 31,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 32,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 35,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 36,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 37,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 38,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 40,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 41,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 43,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 33,
#                "SENTENCE SIMILARITY SCORE": 0.3198397031311171
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 23,
#                "SENTENCE SIMILARITY SCORE": 0.2997574832583734
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.2917269071521711
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.2863882370409225
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.2822143330050316
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 27,
#                "SENTENCE SIMILARITY SCORE": 0.2789661944359821
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.2772057827393423
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.2690509745990061
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 42,
#                "SENTENCE SIMILARITY SCORE": 0.2434765373237497
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 29,
#                "SENTENCE SIMILARITY SCORE": 0.21048476247143055
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.024605475798312716
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 19,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 20,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 21,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 22,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 24,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 25,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 26,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 28,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 30,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 31,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 32,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 34,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 35,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 36,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 37,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 38,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 39,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 40,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 41,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 43,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.8456204373549459
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.6978020945956592
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.07944598783734702
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 37,
#                "SENTENCE SIMILARITY SCORE": 0.06244189286554444
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 43,
#                "SENTENCE SIMILARITY SCORE": 0.059113223431674286
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 31,
#                "SENTENCE SIMILARITY SCORE": 0.03925013731904317
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.03304455818431329
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.022664379471011284
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.020482205196877618
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.01729898955803787
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.0171218224045176
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.016068992503724983
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 34,
#                "SENTENCE SIMILARITY SCORE": 0.01597811257244547
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 24,
#                "SENTENCE SIMILARITY SCORE": 0.009758961434677681
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 19,
#                "SENTENCE SIMILARITY SCORE": 0.0092808208072423
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 25,
#                "SENTENCE SIMILARITY SCORE": 0.009031720554398073
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.007100562685496272
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 26,
#                "SENTENCE SIMILARITY SCORE": 0.005885928112860359
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 40,
#                "SENTENCE SIMILARITY SCORE": 0.0034815932031133793
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 21,
#                "SENTENCE SIMILARITY SCORE": 0.003104607635566821
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 22,
#                "SENTENCE SIMILARITY SCORE": 0.0014320691779722906
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 30,
#                "SENTENCE SIMILARITY SCORE": 0.0010443942558184243
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 32,
#                "SENTENCE SIMILARITY SCORE": 0.0007044793069579375
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.0004794378352566766
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 20,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 23,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 27,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 28,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 29,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 33,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 35,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 36,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 38,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 39,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 41,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 42,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 4",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.906815072816337
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.6768385233234667
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 40,
#                "SENTENCE SIMILARITY SCORE": 0.004524436396006445
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 26,
#                "SENTENCE SIMILARITY SCORE": 0.004039825703289608
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0038249276025906723
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 37,
#                "SENTENCE SIMILARITY SCORE": 0.0034100260867900587
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 25,
#                "SENTENCE SIMILARITY SCORE": 0.003093276528417643
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 22,
#                "SENTENCE SIMILARITY SCORE": 0.0018610175090595909
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 31,
#                "SENTENCE SIMILARITY SCORE": 0.0012120354342899642
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.001189873202526566
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 32,
#                "SENTENCE SIMILARITY SCORE": 0.0009154923136291782
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.0005620454476644339
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 19,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 20,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 21,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 23,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 24,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 27,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 28,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 29,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 30,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 33,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 34,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 35,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 36,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 38,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 39,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 41,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 42,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 43,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 5",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.6899277101559276
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.07848234047449969
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 43,
#                "SENTENCE SIMILARITY SCORE": 0.024396669115860328
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 37,
#                "SENTENCE SIMILARITY SCORE": 0.024049803692102224
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.021201644507545095
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.016481167262808
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.016376222734174932
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 31,
#                "SENTENCE SIMILARITY SCORE": 0.014824581186362495
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.014664414223287493
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 28,
#                "SENTENCE SIMILARITY SCORE": 0.014543367214192153
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.013308436093355244
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.011158366886784619
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.007020142868108551
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 24,
#                "SENTENCE SIMILARITY SCORE": 0.0065956536714710245
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.005179541907474477
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 25,
#                "SENTENCE SIMILARITY SCORE": 0.0029652188011370173
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 21,
#                "SENTENCE SIMILARITY SCORE": 0.002720735999138863
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 30,
#                "SENTENCE SIMILARITY SCORE": 0.0013688095662707516
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 19,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 20,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 22,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 23,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 26,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 27,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 29,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 32,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 33,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 34,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 35,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 36,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 38,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 39,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 40,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 41,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 42,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 6",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 33,
#                "SENTENCE SIMILARITY SCORE": 0.6137098312703442
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.2917269071521711
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 23,
#                "SENTENCE SIMILARITY SCORE": 0.27906760713339074
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.26662113370251617
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.2627353210814632
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 27,
#                "SENTENCE SIMILARITY SCORE": 0.25971137569651676
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.2580724712247727
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.2504805246631118
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 42,
#                "SENTENCE SIMILARITY SCORE": 0.22667128748708068
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 29,
#                "SENTENCE SIMILARITY SCORE": 0.19595667258225624
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.13858739898516909
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 34,
#                "SENTENCE SIMILARITY SCORE": 0.10179434304343585
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 19,
#                "SENTENCE SIMILARITY SCORE": 0.10117554384555219
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.07399158804477313
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.07386983414457855
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 28,
#                "SENTENCE SIMILARITY SCORE": 0.062190299055616544
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 24,
#                "SENTENCE SIMILARITY SCORE": 0.059866198219844846
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.05307511102874515
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 26,
#                "SENTENCE SIMILARITY SCORE": 0.045210334673816716
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 22,
#                "SENTENCE SIMILARITY SCORE": 0.041653888359542035
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 21,
#                "SENTENCE SIMILARITY SCORE": 0.041236623692445545
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.03961842485001857
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 25,
#                "SENTENCE SIMILARITY SCORE": 0.03461735167795633
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 20,
#                "SENTENCE SIMILARITY SCORE": 0.026906302912942718
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.01814743474717856
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 30,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 31,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 32,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 35,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 36,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 37,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 38,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 39,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 40,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 41,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 43,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 7",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000007
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.16743996250823892
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
# ...
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 43,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 28",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 28,
#                "SENTENCE SIMILARITY SCORE": 0.9702621330705745
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.14973297312498318
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.13739364945790516
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.11711532350782945
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0841467815695868
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 24,
#                "SENTENCE SIMILARITY SCORE": 0.08252130928966987
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 34,
#                "SENTENCE SIMILARITY SCORE": 0.07633737973751223
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.06348843388622624
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 21,
#                "SENTENCE SIMILARITY SCORE": 0.06124232093839693
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 26,
#                "SENTENCE SIMILARITY SCORE": 0.05589328826629407
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 22,
#                "SENTENCE SIMILARITY SCORE": 0.046823044204422924
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 19,
#                "SENTENCE SIMILARITY SCORE": 0.04434025226859618
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 25,
#                "SENTENCE SIMILARITY SCORE": 0.04279724161104836
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.04008992742271503
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 33,
#                "SENTENCE SIMILARITY SCORE": 0.034649071447260246
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.019355052157764566
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.015805355031189672
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.014645659441475077
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 30,
#                "SENTENCE SIMILARITY SCORE": 0.011898541555997339
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.006374836830306947
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 31,
#                "SENTENCE SIMILARITY SCORE": 0.0035235213489195993
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0030312196266897686
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.0009118517171674762
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 20,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 23,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 27,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 29,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 32,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 35,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 36,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 37,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 38,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 39,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 40,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 41,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 42,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 43,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 29",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 41,
#                "SENTENCE SIMILARITY SCORE": 0.5648436771633875
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 43,
#                "SENTENCE SIMILARITY SCORE": 0.05330757315552874
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 31,
#                "SENTENCE SIMILARITY SCORE": 0.033111905728720394
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 40,
#                "SENTENCE SIMILARITY SCORE": 0.022535333946346745
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.015351812801606525
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.011784381796759578
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 24,
#                "SENTENCE SIMILARITY SCORE": 0.010565269043800394
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.010561322318541216
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 22,
#                "SENTENCE SIMILARITY SCORE": 0.008070269060108867
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 20,
#                "SENTENCE SIMILARITY SCORE": 0.007365446695624954
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 19,
#                "SENTENCE SIMILARITY SCORE": 0.005755298347604932
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 37,
#                "SENTENCE SIMILARITY SCORE": 0.004976562982138515
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.004447560212139299
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 39,
#                "SENTENCE SIMILARITY SCORE": 0.0032993967420077755
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 38,
#                "SENTENCE SIMILARITY SCORE": 0.0022263062313014298
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 32,
#                "SENTENCE SIMILARITY SCORE": 0.0016528634955186301
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 21,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 23,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 25,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 26,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 27,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 28,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 29,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 30,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 33,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 34,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 35,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 36,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2547rfs",
#                "MATCHED SENTENCE ID": 42,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# # Testing

# %% [markdown]
# ## Case # 1

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hjres27enr'
B_doc_name = 'BILLS-117hjres27ih'


A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_tfidf_vectorized_transformation(A_doc, doc_tfidf_vectorizer)
B_doc_vectorized = document_tfidf_vectorized_transformation(B_doc, doc_tfidf_vectorizer)

A_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(A_section_doc, sec_tfidf_vectorizer)
B_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(B_section_doc, sec_tfidf_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hjres27enr",
#           "MATCHED DOCUMENT ID: BILLS-117hjres27ih",
#           "DOCUMENT SIMILARITY SCORE: 0.9999999999999998",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hjres27ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 2

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr293eh'
B_doc_name = 'BILLS-117hr293ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_tfidf_vectorized_transformation(A_doc, doc_tfidf_vectorizer)
B_doc_vectorized = document_tfidf_vectorized_transformation(B_doc, doc_tfidf_vectorizer)

A_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(A_section_doc, sec_tfidf_vectorizer)
B_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(B_section_doc, sec_tfidf_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr293eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr293ih",
#           "DOCUMENT SIMILARITY SCORE: 0.9999999999999997",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr293ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000004
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr293ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr293ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr293ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999998
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr293ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr293ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr293ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr293ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr293ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 3

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr335enr'
B_doc_name = 'BILLS-117hr335ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_tfidf_vectorized_transformation(A_doc, doc_tfidf_vectorizer)
B_doc_vectorized = document_tfidf_vectorized_transformation(B_doc, doc_tfidf_vectorizer)

A_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(A_section_doc, sec_tfidf_vectorizer)
B_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(B_section_doc, sec_tfidf_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr335enr",
#           "MATCHED DOCUMENT ID: BILLS-117hr335ih",
#           "DOCUMENT SIMILARITY SCORE: 1.0000000000000036",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr335ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999998
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 4

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr335enr'
B_doc_name = 'BILLS-117hr335ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_tfidf_vectorized_transformation(A_doc, doc_tfidf_vectorizer)
B_doc_vectorized = document_tfidf_vectorized_transformation(B_doc, doc_tfidf_vectorizer)

A_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(A_section_doc, sec_tfidf_vectorizer)
B_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(B_section_doc, sec_tfidf_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr335enr",
#           "MATCHED DOCUMENT ID: BILLS-117hr335ih",
#           "DOCUMENT SIMILARITY SCORE: 1.0000000000000036",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr335ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999998
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 5

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr1195eh'
B_doc_name = 'BILLS-117hr1195rh'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_tfidf_vectorized_transformation(A_doc, doc_tfidf_vectorizer)
B_doc_vectorized = document_tfidf_vectorized_transformation(B_doc, doc_tfidf_vectorizer)

A_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(A_section_doc, sec_tfidf_vectorizer)
B_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(B_section_doc, sec_tfidf_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr1195eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr1195rh",
#           "DOCUMENT SIMILARITY SCORE: 0.977852488703694",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.2168741428291012
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.04678072486075494
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0395936129650904
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 1.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.14320693022600067
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0395936129650904
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0030275725725756684
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.9576077165389069
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.13663754616640023
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0926593309183447
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.060141395349216475
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.04402961714564768
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.02020911921261582
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0019118250065899875
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 4",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.9885502373747107
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.049440671083954855
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.019762260651191226
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.016266645437083862
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.007651336719141572
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0047398287223494595
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 5",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.9695275296435186
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.05956827927666497
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.048774781441238466
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.014771428972442345
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.010472567541941157
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.006801080570673262
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.002966305282849773
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 6",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.8647889347234706
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.1069021336928407
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.01779249222354383
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.005787714453599985
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.003979264430033639
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 7",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000222
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.016379011674495954
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.015076524143783125
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0020312817919662064
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0016580465900598584
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 8",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.2168741428291012
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.14320693022600067
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.09141528531440488
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.021339602489026492
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.010688872260634742
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.007704190389655771
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0016580465900598584
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 6

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr1205eh'
B_doc_name = 'BILLS-117hr1205ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_tfidf_vectorized_transformation(A_doc, doc_tfidf_vectorizer)
B_doc_vectorized = document_tfidf_vectorized_transformation(B_doc, doc_tfidf_vectorizer)

A_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(A_section_doc, sec_tfidf_vectorizer)
B_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(B_section_doc, sec_tfidf_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr1205eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr1205ih",
#           "DOCUMENT SIMILARITY SCORE: 0.9999999999999863",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1205ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1205ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1205ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1205ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999997
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1205ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.9782436500397811
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1205ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1205ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000022
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1205ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.9782436500397811
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1205ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 7

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
#A_doc_name = 'BILLS-117hr1251eh'
#B_doc_name = 'BILLS-117hr1251ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_tfidf_vectorized_transformation(A_doc, doc_tfidf_vectorizer)
B_doc_vectorized = document_tfidf_vectorized_transformation(B_doc, doc_tfidf_vectorizer)

A_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(A_section_doc, sec_tfidf_vectorizer)
B_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(B_section_doc, sec_tfidf_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr1251eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr1251ih",
#           "DOCUMENT SIMILARITY SCORE: 0.9289690386554342",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000004
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.1161022452774018
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.03667330745972546
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.008909819256373155
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.004323221271352894
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.9761742471393479
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.06453370867154076
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.009629132932017156
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.004553473705778198
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.004205306094897842
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.003546054062595339
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.003034449231008192
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0011523992293525152
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 1.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.026155580577038203
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.00483464259619518
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.002503151182477366
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 4",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000013
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.06479404369718757
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.020696494815561645
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.00976049364488038
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.007864786361736867
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.00518883303466395
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.002367687444281376
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.0014794028725985293
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 5",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.7189346671282896
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.027977892738955585
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.019850769416274786
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.01868878414987645
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.01765690512313611
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.017614834803689576
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.01597497102913921
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.008764199437103003
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.002290675294215659
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0011753793908740652
#           },
#           "ORIGINAL SENTENCE ID: 6",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000004
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.025165726075933273
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.022554819331801715
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.010166786196937542
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.00909270627892328
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.008909819256373155
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.007864786361736867
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.004571842845230715
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0032123837344528424
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.002503151182477366
#           },
#           "ORIGINAL SENTENCE ID: 7",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.9482503987585031
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.021906568693928426
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.018274140584392584
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.014306971527064725
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.005039700191919505
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0034580304871954506
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.002015081524080949
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 8",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000013
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.026808288995018133
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.026155580577038203
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.00976049364488038
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.004323221271352894
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0032123837344528424
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0020747110307190297
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.001157048115788839
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0006848682996024273
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 9",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.026808288995018133
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.01881490182618862
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.018598916513334684
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.010166786196937542
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.004222270693595244
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.002367687444281376
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 10",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999969
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.1161022452774018
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.00909270627892328
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.009055882739145928
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.003046690483442622
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.003002607813925871
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0014794028725985293
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 8

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr1257eh'
B_doc_name = 'BILLS-117hr1257rfs'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_tfidf_vectorized_transformation(A_doc, doc_tfidf_vectorizer)
B_doc_vectorized = document_tfidf_vectorized_transformation(B_doc, doc_tfidf_vectorizer)

A_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(A_section_doc, sec_tfidf_vectorizer)
B_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(B_section_doc, sec_tfidf_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr1257eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr1257rfs",
#           "DOCUMENT SIMILARITY SCORE: 1.0000000000000009",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1257rfs",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1257rfs",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1257rfs",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1257rfs",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1257rfs",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0018174727743773059
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1257rfs",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1257rfs",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 1.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1257rfs",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0018174727743773059
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1257rfs",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 9

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr1195eh'
B_doc_name = 'BILLS-117hr1195rh'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_tfidf_vectorized_transformation(A_doc, doc_tfidf_vectorizer)
B_doc_vectorized = document_tfidf_vectorized_transformation(B_doc, doc_tfidf_vectorizer)

A_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(A_section_doc, sec_tfidf_vectorizer)
B_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(B_section_doc, sec_tfidf_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr1195eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr1195rh",
#           "DOCUMENT SIMILARITY SCORE: 0.977852488703694",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.2168741428291012
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.04678072486075494
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0395936129650904
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 1.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.14320693022600067
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0395936129650904
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0030275725725756684
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.9576077165389069
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.13663754616640023
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0926593309183447
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.060141395349216475
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.04402961714564768
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.02020911921261582
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0019118250065899875
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 4",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.9885502373747107
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.049440671083954855
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.019762260651191226
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.016266645437083862
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.007651336719141572
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0047398287223494595
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 5",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.9695275296435186
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.05956827927666497
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.048774781441238466
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.014771428972442345
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.010472567541941157
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.006801080570673262
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.002966305282849773
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 6",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.8647889347234706
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.1069021336928407
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.01779249222354383
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.005787714453599985
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.003979264430033639
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 7",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000222
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.016379011674495954
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.015076524143783125
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0020312817919662064
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0016580465900598584
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 8",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.2168741428291012
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.14320693022600067
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.09141528531440488
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.021339602489026492
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.010688872260634742
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.007704190389655771
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0016580465900598584
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 10

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr1262eh'
B_doc_name = 'BILLS-117hr1262ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_tfidf_vectorized_transformation(A_doc, doc_tfidf_vectorizer)
B_doc_vectorized = document_tfidf_vectorized_transformation(B_doc, doc_tfidf_vectorizer)

A_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(A_section_doc, sec_tfidf_vectorizer)
B_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(B_section_doc, sec_tfidf_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr1262eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr1262ih",
#           "DOCUMENT SIMILARITY SCORE: 0.9407637689064062",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1262ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1262ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1262ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.9408737010231012
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1262ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 11

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr1280eh'
B_doc_name = 'BILLS-117hr1280ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_tfidf_vectorized_transformation(A_doc, doc_tfidf_vectorizer)
B_doc_vectorized = document_tfidf_vectorized_transformation(B_doc, doc_tfidf_vectorizer)

A_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(A_section_doc, sec_tfidf_vectorizer)
B_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(B_section_doc, sec_tfidf_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr1280eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr1280ih",
#           "DOCUMENT SIMILARITY SCORE: 0.9998036377384408",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000007
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 45,
#                "SENTENCE SIMILARITY SCORE": 0.05517825493007554
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 58,
#                "SENTENCE SIMILARITY SCORE": 0.0533766438665852
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 42,
#                "SENTENCE SIMILARITY SCORE": 0.046864767212212805
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 59,
#                "SENTENCE SIMILARITY SCORE": 0.046404303581745104
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 28,
#                "SENTENCE SIMILARITY SCORE": 0.04314994723656908
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.03557714633821709
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 57,
#                "SENTENCE SIMILARITY SCORE": 0.033142430265688784
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 24,
#                "SENTENCE SIMILARITY SCORE": 0.03265650292508519
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 37,
#                "SENTENCE SIMILARITY SCORE": 0.024873958831434638
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 38,
#                "SENTENCE SIMILARITY SCORE": 0.0217141090480278
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 60,
#                "SENTENCE SIMILARITY SCORE": 0.019531868260443314
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 41,
#                "SENTENCE SIMILARITY SCORE": 0.01778876848229714
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.01774863509803093
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.014356824403280696
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 32,
#                "SENTENCE SIMILARITY SCORE": 0.014336330776769293
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.013230642277549437
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.011438455337782368
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 39,
#                "SENTENCE SIMILARITY SCORE": 0.008528260605809518
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 29,
#                "SENTENCE SIMILARITY SCORE": 0.008483846605931392
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0081713041450093
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 40,
#                "SENTENCE SIMILARITY SCORE": 0.007134298001894276
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.007032920306849678
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 43,
#                "SENTENCE SIMILARITY SCORE": 0.006554297404836387
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.006510139532463072
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 46,
#                "SENTENCE SIMILARITY SCORE": 0.005958756382056811
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.004315735940774593
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.0034041254362615803
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 30,
#                "SENTENCE SIMILARITY SCORE": 0.0032848070539654734
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 47,
#                "SENTENCE SIMILARITY SCORE": 0.0029977914005562935
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.0022509511167237203
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 34,
#                "SENTENCE SIMILARITY SCORE": 0.002077385171306151
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 52,
#                "SENTENCE SIMILARITY SCORE": 0.002018585232812279
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0018498530150378853
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 19,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 20,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 21,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 22,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 23,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 25,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 26,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 27,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 31,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 33,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 35,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 36,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 44,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 48,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 49,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 50,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 51,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 53,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 54,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 55,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 56,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 61,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 62,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 63,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.999999999999999
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 32,
#                "SENTENCE SIMILARITY SCORE": 0.13924635367741678
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 44,
#                "SENTENCE SIMILARITY SCORE": 0.11277781134881822
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 63,
#                "SENTENCE SIMILARITY SCORE": 0.09489774815321107
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.08607292079149029
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 38,
#                "SENTENCE SIMILARITY SCORE": 0.08209892525701748
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 61,
#                "SENTENCE SIMILARITY SCORE": 0.06427990751247362
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.0569020027455579
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 25,
#                "SENTENCE SIMILARITY SCORE": 0.05477907877212798
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.054127210531321995
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 53,
#                "SENTENCE SIMILARITY SCORE": 0.04963240675827708
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 41,
#                "SENTENCE SIMILARITY SCORE": 0.04737137721768183
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.04558047801851076
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 58,
#                "SENTENCE SIMILARITY SCORE": 0.0410524868815425
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 40,
#                "SENTENCE SIMILARITY SCORE": 0.032569350529843645
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.029607815360985442
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.029143852112824675
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 59,
#                "SENTENCE SIMILARITY SCORE": 0.028851893622146716
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 42,
#                "SENTENCE SIMILARITY SCORE": 0.02788688770021539
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 19,
#                "SENTENCE SIMILARITY SCORE": 0.023069958578800773
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 46,
#                "SENTENCE SIMILARITY SCORE": 0.021934865192809586
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 54,
#                "SENTENCE SIMILARITY SCORE": 0.012804346995239045
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 39,
#                "SENTENCE SIMILARITY SCORE": 0.01234852932143837
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 47,
#                "SENTENCE SIMILARITY SCORE": 0.01190731600095173
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 51,
#                "SENTENCE SIMILARITY SCORE": 0.009352409286772223
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 22,
#                "SENTENCE SIMILARITY SCORE": 0.008550325260003109
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 49,
#                "SENTENCE SIMILARITY SCORE": 0.0074106874820045075
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.007387228305371999
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 29,
#                "SENTENCE SIMILARITY SCORE": 0.00664400158081073
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.006190734330688752
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.005923435405075311
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 21,
#                "SENTENCE SIMILARITY SCORE": 0.005052685717498917
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.003461520678370303
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 37,
#                "SENTENCE SIMILARITY SCORE": 0.0029945679558347786
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 43,
#                "SENTENCE SIMILARITY SCORE": 0.002624723615465328
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 30,
#                "SENTENCE SIMILARITY SCORE": 0.0024957732312531062
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 34,
#                "SENTENCE SIMILARITY SCORE": 0.00213404992184089
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0018498530150378853
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 36,
#                "SENTENCE SIMILARITY SCORE": 0.0014631678018578774
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 60,
#                "SENTENCE SIMILARITY SCORE": 0.0011382327395800813
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.00046596992862399166
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.0004133081962412362
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 20,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 23,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 24,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 26,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 27,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 28,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 31,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 33,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 35,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 45,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 48,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 50,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 52,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 55,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 56,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 57,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 62,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 58,
#                "SENTENCE SIMILARITY SCORE": 0.02131637710570696
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.014356824403280696
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 40,
#                "SENTENCE SIMILARITY SCORE": 0.010254972738785798
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 61,
#                "SENTENCE SIMILARITY SCORE": 0.008063244427510146
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 41,
#                "SENTENCE SIMILARITY SCORE": 0.005783484495801084
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0054385929417404425
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 44,
#                "SENTENCE SIMILARITY SCORE": 0.004149135164710481
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 39,
#                "SENTENCE SIMILARITY SCORE": 0.003522016484111706
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 32,
#                "SENTENCE SIMILARITY SCORE": 0.0034358615048750087
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.003279636500867312
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 43,
#                "SENTENCE SIMILARITY SCORE": 0.0032347392415448817
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 38,
#                "SENTENCE SIMILARITY SCORE": 0.00299651427343517
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.002871817477417083
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 60,
#                "SENTENCE SIMILARITY SCORE": 0.002396322994560683
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 36,
#                "SENTENCE SIMILARITY SCORE": 0.0023323016071353287
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0020898630330918005
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 53,
#                "SENTENCE SIMILARITY SCORE": 0.002056201147133855
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 25,
#                "SENTENCE SIMILARITY SCORE": 0.0018787916589892517
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0016246339683809612
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.0013223135784763682
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.0009363560261773541
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 46,
#                "SENTENCE SIMILARITY SCORE": 0.0007195312166143165
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 19,
#                "SENTENCE SIMILARITY SCORE": 0.0006771327156381429
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 47,
#                "SENTENCE SIMILARITY SCORE": 0.0006760576441158311
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.00046596992862399166
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 20,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 21,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 22,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 23,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 24,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 26,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 27,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 28,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 29,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 30,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 31,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 33,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 34,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 35,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 37,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 42,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 45,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 48,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 49,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 50,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 51,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 52,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 54,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 55,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 56,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 57,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 59,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 62,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 63,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 4",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 42,
#                "SENTENCE SIMILARITY SCORE": 0.09380229659301687
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 63,
#                "SENTENCE SIMILARITY SCORE": 0.028702457806653228
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 41,
#                "SENTENCE SIMILARITY SCORE": 0.028232485397869166
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 19,
#                "SENTENCE SIMILARITY SCORE": 0.02244744701907949
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.019710312857354487
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.01774863509803093
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.01440906520467163
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 43,
#                "SENTENCE SIMILARITY SCORE": 0.014309659950751159
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 61,
#                "SENTENCE SIMILARITY SCORE": 0.01203222392759287
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 27,
#                "SENTENCE SIMILARITY SCORE": 0.01042850626056225
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 58,
#                "SENTENCE SIMILARITY SCORE": 0.007791211688310012
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.007387228305371999
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.007190037345545965
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 25,
#                "SENTENCE SIMILARITY SCORE": 0.005692758601920362
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0054385929417404425
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 21,
#                "SENTENCE SIMILARITY SCORE": 0.004995631418218794
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 39,
#                "SENTENCE SIMILARITY SCORE": 0.004185605521140448
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 40,
#                "SENTENCE SIMILARITY SCORE": 0.00415767049066704
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 44,
#                "SENTENCE SIMILARITY SCORE": 0.004070537396357084
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 38,
#                "SENTENCE SIMILARITY SCORE": 0.0035610925569616414
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 46,
#                "SENTENCE SIMILARITY SCORE": 0.0034016165129911284
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 32,
#                "SENTENCE SIMILARITY SCORE": 0.003354213386797317
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 60,
#                "SENTENCE SIMILARITY SCORE": 0.002957858593835147
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0024836176347262456
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 36,
#                "SENTENCE SIMILARITY SCORE": 0.002216189080129831
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 53,
#                "SENTENCE SIMILARITY SCORE": 0.002161253216099032
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 31,
#                "SENTENCE SIMILARITY SCORE": 0.001927525340987593
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.0016646882861133514
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.0012908907708230367
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 49,
#                "SENTENCE SIMILARITY SCORE": 0.0010280394407926922
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0009417413041228772
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 47,
#                "SENTENCE SIMILARITY SCORE": 0.0006424004356229339
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 54,
#                "SENTENCE SIMILARITY SCORE": 0.00017893764052737493
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 20,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 22,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 23,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 24,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 26,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 28,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 29,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 30,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 33,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 34,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 35,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 37,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 45,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 48,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 50,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 51,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 52,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 55,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 56,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 57,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 59,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 62,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 5",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999993
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.07797150637023707
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 63,
#                "SENTENCE SIMILARITY SCORE": 0.07411349667716413
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 59,
#                "SENTENCE SIMILARITY SCORE": 0.05382186489280366
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 40,
#                "SENTENCE SIMILARITY SCORE": 0.05377939819141215
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.05326139696163853
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 38,
#                "SENTENCE SIMILARITY SCORE": 0.04955835938269185
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 19,
#                "SENTENCE SIMILARITY SCORE": 0.04533242652776595
#           },
# ...
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 33,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 35,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 36,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 38,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 39,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 40,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 42,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 43,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 44,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 45,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 46,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 47,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 48,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 49,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 50,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 51,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 52,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 53,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 54,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 55,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 56,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 57,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 58,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 59,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 61,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 63,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 63",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 63,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000016
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.09489774815321107
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.07892808704544385
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.07411349667716413
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 32,
#                "SENTENCE SIMILARITY SCORE": 0.06875752722597833
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 44,
#                "SENTENCE SIMILARITY SCORE": 0.05838404375619719
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.03289538957488413
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 38,
#                "SENTENCE SIMILARITY SCORE": 0.029982714880448375
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.028702457806653228
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 25,
#                "SENTENCE SIMILARITY SCORE": 0.026341324034582243
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.026029674997262817
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 53,
#                "SENTENCE SIMILARITY SCORE": 0.022039297082383395
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.02091088569671589
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 19,
#                "SENTENCE SIMILARITY SCORE": 0.019360008790099453
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.01641551848556986
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.015008239655475519
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 51,
#                "SENTENCE SIMILARITY SCORE": 0.005438834216394611
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 59,
#                "SENTENCE SIMILARITY SCORE": 0.002562635465026373
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 34,
#                "SENTENCE SIMILARITY SCORE": 0.0024328095871114994
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 49,
#                "SENTENCE SIMILARITY SCORE": 0.00152776366567341
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.0010370024774774707
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 60,
#                "SENTENCE SIMILARITY SCORE": 0.001011785682635301
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 46,
#                "SENTENCE SIMILARITY SCORE": 0.0005503376338206483
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 54,
#                "SENTENCE SIMILARITY SCORE": 0.0002659182272309143
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 20,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 21,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 22,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 23,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 24,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 26,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 27,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 28,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 29,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 30,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 31,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 33,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 35,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 36,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 37,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 39,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 40,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 41,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 42,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 43,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 45,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 47,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 48,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 50,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 52,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 55,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 56,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 57,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 58,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 61,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 62,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 12

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr1314eh'
B_doc_name = 'BILLS-117hr1314ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_tfidf_vectorized_transformation(A_doc, doc_tfidf_vectorizer)
B_doc_vectorized = document_tfidf_vectorized_transformation(B_doc, doc_tfidf_vectorizer)

A_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(A_section_doc, sec_tfidf_vectorizer)
B_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(B_section_doc, sec_tfidf_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr1314eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr1314ih",
#           "DOCUMENT SIMILARITY SCORE: 1.0000000000000024",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1314ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1314ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1314ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000007
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1314ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 13

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr1318enr'
B_doc_name = 'BILLS-117hr1318eh'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_tfidf_vectorized_transformation(A_doc, doc_tfidf_vectorizer)
B_doc_vectorized = document_tfidf_vectorized_transformation(B_doc, doc_tfidf_vectorizer)

A_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(A_section_doc, sec_tfidf_vectorizer)
B_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(B_section_doc, sec_tfidf_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr1318enr",
#           "MATCHED DOCUMENT ID: BILLS-117hr1318eh",
#           "DOCUMENT SIMILARITY SCORE: 1.000000000000002",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1318eh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1318eh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1318eh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1318eh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1318eh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000013
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1318eh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0023832265065286545
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1318eh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.002118306441458543
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1318eh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1318eh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000047
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1318eh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.897228790182291
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1318eh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.002118306441458543
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1318eh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 4",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1318eh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999992
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1318eh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.897228790182291
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1318eh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0023832265065286545
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1318eh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 14

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr1324eh'
B_doc_name = 'BILLS-117hr1324ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_tfidf_vectorized_transformation(A_doc, doc_tfidf_vectorizer)
B_doc_vectorized = document_tfidf_vectorized_transformation(B_doc, doc_tfidf_vectorizer)

A_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(A_section_doc, sec_tfidf_vectorizer)
B_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(B_section_doc, sec_tfidf_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr1324eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr1324ih",
#           "DOCUMENT SIMILARITY SCORE: 0.9994893123971358",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1324ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1324ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.012047491668665698
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1324ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.006203334326419799
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1324ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.9993872413549618
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1324ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.9903066025066113
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1324ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.012050336612085483
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1324ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.9993501523447761
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1324ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.9903207563779851
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1324ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.006204887888438149
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 15

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr1333eh'
B_doc_name = 'BILLS-117hr1333ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_tfidf_vectorized_transformation(A_doc, doc_tfidf_vectorizer)
B_doc_vectorized = document_tfidf_vectorized_transformation(B_doc, doc_tfidf_vectorizer)

A_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(A_section_doc, sec_tfidf_vectorizer)
B_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(B_section_doc, sec_tfidf_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr1333eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr1333ih",
#           "DOCUMENT SIMILARITY SCORE: 0.9689457170872295",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1333ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1333ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1333ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1333ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1333ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.6428806984992917
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1333ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.010813089759222277
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1333ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.007482796688439745
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1333ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1333ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000018
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1333ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.05810802552354137
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1333ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.013233882477733503
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1333ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 4",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1333ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.9725946786659615
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1333ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0564239066583061
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1333ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.00912875285813554
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1333ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 16

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr1392eh'
B_doc_name = 'BILLS-117hr1392ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_tfidf_vectorized_transformation(A_doc, doc_tfidf_vectorizer)
B_doc_vectorized = document_tfidf_vectorized_transformation(B_doc, doc_tfidf_vectorizer)

A_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(A_section_doc, sec_tfidf_vectorizer)
B_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(B_section_doc, sec_tfidf_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr1392eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr1392ih",
#           "DOCUMENT SIMILARITY SCORE: 0.9018812516324968",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.3236916968453651
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.003317250676935142
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.9038112691380729
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.16685818700686122
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.08518560439178402
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.031747552255861476
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.020978038628270725
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 4",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.11963193065750168
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.10793995650772195
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.09926286280499182
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.009996839759257551
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 5",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.9467274325590422
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.18375661102570082
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.11803120578962617
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.10287936978318155
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0057924534329204976
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 6",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.9586253525731965
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.10480645422390276
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.09903019107251779
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.03618758216384828
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0016527725855354683
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 7",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.00396304448044447
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 17

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr1602eh'
B_doc_name = 'BILLS-117hr1602ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_tfidf_vectorized_transformation(A_doc, doc_tfidf_vectorizer)
B_doc_vectorized = document_tfidf_vectorized_transformation(B_doc, doc_tfidf_vectorizer)

A_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(A_section_doc, sec_tfidf_vectorizer)
B_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(B_section_doc, sec_tfidf_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr1602eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr1602ih",
#           "DOCUMENT SIMILARITY SCORE: 0.9958174662617439",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1602ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1602ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1602ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.995896995612144
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1602ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 18

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr1651enr'
B_doc_name = 'BILLS-117hr1651ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_tfidf_vectorized_transformation(A_doc, doc_tfidf_vectorizer)
B_doc_vectorized = document_tfidf_vectorized_transformation(B_doc, doc_tfidf_vectorizer)

A_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(A_section_doc, sec_tfidf_vectorizer)
B_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(B_section_doc, sec_tfidf_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr1651enr",
#           "MATCHED DOCUMENT ID: BILLS-117hr1651ih",
#           "DOCUMENT SIMILARITY SCORE: 0.8230106276686338",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1651ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1651ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.2922331359232185
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1651ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.892049726610896
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1651ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.3312603995008717
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1651ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1651ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 19

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr1711eh'
B_doc_name = 'BILLS-117hr1711ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_tfidf_vectorized_transformation(A_doc, doc_tfidf_vectorizer)
B_doc_vectorized = document_tfidf_vectorized_transformation(B_doc, doc_tfidf_vectorizer)

A_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(A_section_doc, sec_tfidf_vectorizer)
B_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(B_section_doc, sec_tfidf_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr1711eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr1711ih",
#           "DOCUMENT SIMILARITY SCORE: 0.9999999999999841",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1711ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1711ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1711ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1711ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1711ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000024
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1711ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.003049908677159866
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1711ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1711ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1711ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 1.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1711ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.003049908677159866
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1711ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1711ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 4",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1711ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1711ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1711ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1711ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 20

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr1833eh'
B_doc_name = 'BILLS-117hr1833ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_tfidf_vectorized_transformation(A_doc, doc_tfidf_vectorizer)
B_doc_vectorized = document_tfidf_vectorized_transformation(B_doc, doc_tfidf_vectorizer)

A_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(A_section_doc, sec_tfidf_vectorizer)
B_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(B_section_doc, sec_tfidf_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr1833eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr1833ih",
#           "DOCUMENT SIMILARITY SCORE: 0.7345620477499715",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1833ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1833ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.019232336411061347
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1833ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.7305223234833066
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1833ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.012818069894104991
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 21

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr2008eh'
B_doc_name = 'BILLS-117hr2008ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_tfidf_vectorized_transformation(A_doc, doc_tfidf_vectorizer)
B_doc_vectorized = document_tfidf_vectorized_transformation(B_doc, doc_tfidf_vectorizer)

A_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(A_section_doc, sec_tfidf_vectorizer)
B_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(B_section_doc, sec_tfidf_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr2008eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr2008ih",
#           "DOCUMENT SIMILARITY SCORE: 1.0000000000000002",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2008ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2008ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2008ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 1.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2008ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 22

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr2016rh'
B_doc_name = 'BILLS-117hr2016ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_tfidf_vectorized_transformation(A_doc, doc_tfidf_vectorizer)
B_doc_vectorized = document_tfidf_vectorized_transformation(B_doc, doc_tfidf_vectorizer)

A_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(A_section_doc, sec_tfidf_vectorizer)
B_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(B_section_doc, sec_tfidf_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr2016rh",
#           "MATCHED DOCUMENT ID: BILLS-117hr2016ih",
#           "DOCUMENT SIMILARITY SCORE: 0.9999999999999883",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2016ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2016ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2016ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2016ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999902
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2016ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.9345395275399037
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2016ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2016ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 1.000000000000001
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2016ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.9345395275399037
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2016ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 23

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr2027eh'
B_doc_name = 'BILLS-117hr2027ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_tfidf_vectorized_transformation(A_doc, doc_tfidf_vectorizer)
B_doc_vectorized = document_tfidf_vectorized_transformation(B_doc, doc_tfidf_vectorizer)

A_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(A_section_doc, sec_tfidf_vectorizer)
B_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(B_section_doc, sec_tfidf_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr2027eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr2027ih",
#           "DOCUMENT SIMILARITY SCORE: 1.0000000000000078",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 1.000000000000003
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.11094755693016534
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.09958785106814073
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.07438926627314588
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999999
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.1940322928835665
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.18430224839505988
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.07438926627314588
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 4",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999984
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.30784040938229995
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.18430224839505988
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.11094755693016534
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.001019923766627367
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 5",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000016
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.30784040938229995
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.1940322928835665
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.09958785106814073
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 6",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 1.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.001019923766627367
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 24

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr2062eh'
B_doc_name = 'BILLS-117hr2062rfs'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_tfidf_vectorized_transformation(A_doc, doc_tfidf_vectorizer)
B_doc_vectorized = document_tfidf_vectorized_transformation(B_doc, doc_tfidf_vectorizer)

A_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(A_section_doc, sec_tfidf_vectorizer)
B_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(B_section_doc, sec_tfidf_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr2062eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr2062rfs",
#           "DOCUMENT SIMILARITY SCORE: 1.0000000000000036",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.999999999999999
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.03799872382339412
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0063519968510978315
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.048296724511363576
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.012826485208315693
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.004337166006048727
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 4",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.048296724511363576
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0020771340525013687
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.002067285190168178
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 5",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 1.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.06489579237847347
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.03609251439131813
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.004337166006048727
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0020771340525013687
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 6",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.03609251439131813
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.028360677276895195
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0063519968510978315
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 7",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999997
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.06489579237847347
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.03799872382339412
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.028360677276895195
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.012826485208315693
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.002067285190168178
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 25

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr1573eh'
B_doc_name = 'BILLS-117hr1573ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_tfidf_vectorized_transformation(A_doc, doc_tfidf_vectorizer)
B_doc_vectorized = document_tfidf_vectorized_transformation(B_doc, doc_tfidf_vectorizer)

A_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(A_section_doc, sec_tfidf_vectorizer)
B_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(B_section_doc, sec_tfidf_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr1573eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr1573ih",
#           "DOCUMENT SIMILARITY SCORE: 0.928393975216383",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1573ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1573ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1573ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.9292457930874963
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1573ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 26

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr2332eh'
B_doc_name = 'BILLS-117hr2332ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_tfidf_vectorized_transformation(A_doc, doc_tfidf_vectorizer)
B_doc_vectorized = document_tfidf_vectorized_transformation(B_doc, doc_tfidf_vectorizer)

A_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(A_section_doc, sec_tfidf_vectorizer)
B_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(B_section_doc, sec_tfidf_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr2332eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr2332ih",
#           "DOCUMENT SIMILARITY SCORE: 0.7037812302306787",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2332ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2332ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2332ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2332ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.7066945664036552
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2332ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.5989373356406876
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2332ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2332ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.7050657206342791
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2332ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.6232850182568194
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2332ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 27

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr2467ih'
B_doc_name = 'BILLS-117hr2467rh'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_tfidf_vectorized_transformation(A_doc, doc_tfidf_vectorizer)
B_doc_vectorized = document_tfidf_vectorized_transformation(B_doc, doc_tfidf_vectorizer)

A_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(A_section_doc, sec_tfidf_vectorizer)
B_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(B_section_doc, sec_tfidf_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr2467ih",
#           "MATCHED DOCUMENT ID: BILLS-117hr2467rh",
#           "DOCUMENT SIMILARITY SCORE: 0.9999999999999997",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000009
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.1692170180717253
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.11127584710523475
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.05201327668990666
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.042012867765771
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.04029878395395586
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.03817148854999953
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.033463551060256
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.029874415045788902
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.029459849449504572
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.01582288829690043
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0049798484335888266
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.003916683659363796
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999986
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.18367146084014027
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.07341277414022511
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.052203229357065735
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.04235546297621457
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.037009198804421106
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.03611564582379826
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.035545436644992566
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.028726198645674335
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.028719372699520792
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.02849445721806564
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.02156976369333233
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.016879574668799753
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.010266843897082165
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.010106769769036909
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.0064886946932652375
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0049798484335888266
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.0036403504966426754
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999999
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.1423426931345177
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.09875081452647819
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.08278195069335198
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.08045427481435015
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.06595905274081759
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.052138667751817205
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.042012867765771
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.02849445721806564
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.026160016741817442
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.016942665139099373
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.01590216166752261
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.014223214852706735
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.008272140254064513
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.007433543459933061
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.00415344060068816
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.0018487643515739957
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 4",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000004
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.1423426931345177
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.04915383588653083
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.04308999623211268
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.03450654087834749
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.033463551060256
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.023128304796342543
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.01874887106102011
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.017928808165635947
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.016879574668799753
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.01670552544719958
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.016188201503723153
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.01530340071366639
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.01364379314375283
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.010889702684230855
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.007793165170576811
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.006250510580307233
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 5",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 1.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.3839116809409902
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.06595905274081759
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.04915383588653083
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.02370212359605454
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.022211975932436737
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.02156976369333233
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.01843149278396622
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.01796411778411142
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.01767089417152974
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.016103897965896626
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.01582288829690043
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.015793909426810776
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.015585384414878707
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.014946184382807058
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.012684619836548502
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.0037329120165255102
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 6",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.3839116809409902
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.038611916071827235
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.037009198804421106
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.029572773143015634
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.026411176195844096
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.023128304796342543
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.021605145051591054
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.017784384553305
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.01647958952632505
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.01590216166752261
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.01483339217245677
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.010473131009448113
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.00854541898388015
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.007738825776510943
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.006257510850297233
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 7",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000018
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.9844086333005685
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.03185025825785789
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.025373919462535387
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.023535017496960305
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.021605145051591054
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.017928808165635947
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.01767089417152974
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.016942665139099373
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.013389855596762434
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.010560097421749615
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.010106769769036909
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.00919993050754617
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.00884471508008194
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.007630160503255194
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.003916683659363796
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 8",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 1.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.9844086333005685
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.032354712444027475
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.025775799402998595
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.023907772342519125
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.015793909426810776
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.01530340071366639
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.014223214852706735
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.013601928247894754
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.010266843897082165
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.008984800397805349
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.008036440712929912
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.0077510093320417965
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.006257510850297233
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 9",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000004
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.18367146084014027
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.0885796732094683
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.08278195069335198
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.07057321200161029
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.06671703878060238
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.05225536514079037
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.05201327668990666
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.042327514120028886
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.04122762669311401
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.03468831395370861
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.029572773143015634
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.02370212359605454
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.020092882082779834
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.01874887106102011
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.013601928247894754
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.013389855596762434
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 10",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.08045427481435015
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.07057321200161029
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.04478517811048312
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.03450654087834749
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.03225387825335541
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.029459849449504572
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.028726198645674335
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.02831306879687497
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.022211975932436737
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.010560097421749615
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.008036440712929912
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.003027795784445014
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.0017029268290004197
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.0015833041919081842
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 11",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999998
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.051206397913099826
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.04122762669311401
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.03611564582379826
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.032354712444027475
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.03185025825785789
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.01647958952632505
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.016103897965896626
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.014179654146227195
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.014162341878157778
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.01364379314375283
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.011922766366273017
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.008350324133904522
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.007433543459933061
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.007359282095146039
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.0015833041919081842
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 12",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.11127584710523475
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.07341277414022511
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.06671703878060238
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.051206397913099826
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.02985498742985514
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.026411176195844096
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.026189443114693952
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.025775799402998595
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.025373919462535387
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.017581445885918656
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.014946184382807058
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.013132453641720821
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.008272140254064513
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.007793165170576811
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.003027795784445014
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.0025980391312726164
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 13",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 1.000000000000001
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.05225536514079037
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.052203229357065735
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.029874415045788902
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.02985498742985514
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.02514227227959432
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.017784384553305
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.015250962888221555
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.014179654146227195
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.004496262200726846
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 14",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.20619038920313268
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.016188201503723153
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.015585384414878707
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0077510093320417965
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.007738825776510943
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.007630160503255194
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.007359282095146039
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.00415344060068816
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0036403504966426754
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.0025980391312726164
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 15",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000009
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.035545436644992566
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.03468831395370861
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.026189443114693952
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.015250962888221555
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.014162341878157778
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.008984800397805349
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.008981212246610616
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.00884471508008194
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.00854541898388015
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.007950745934761593
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.006250510580307233
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0037329120165255102
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0018487643515739957
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.0017029268290004197
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 16",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.09875081452647819
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0885796732094683
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.04478517811048312
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.04235546297621457
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.03817148854999953
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.02881652788518857
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.02514227227959432
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.01843149278396622
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.017581445885918656
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.0145013065408481
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.010889702684230855
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.010473131009448113
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.008981212246610616
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.008350324133904522
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 17",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 1.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.1692170180717253
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.04308999623211268
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.038611916071827235
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.02831306879687497
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.026160016741817442
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.020092882082779834
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.0145013065408481
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.012684619836548502
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.00919993050754617
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0064886946932652375
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.005901975348913727
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 18",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000018
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.20619038920313268
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.052138667751817205
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.042327514120028886
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.04029878395395586
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.03225387825335541
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.02881652788518857
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.028719372699520792
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.023907772342519125
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.023535017496960305
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.01796411778411142
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.01670552544719958
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.01483339217245677
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.013132453641720821
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.011922766366273017
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.007950745934761593
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.005901975348913727
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.004496262200726846
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 28

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr2485eh'
B_doc_name = 'BILLS-117hr2485ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_tfidf_vectorized_transformation(A_doc, doc_tfidf_vectorizer)
B_doc_vectorized = document_tfidf_vectorized_transformation(B_doc, doc_tfidf_vectorizer)

A_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(A_section_doc, sec_tfidf_vectorizer)
B_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(B_section_doc, sec_tfidf_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr2485eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr2485ih",
#           "DOCUMENT SIMILARITY SCORE: 0.998935637661856",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000004
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.035168019110867574
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.02624438633537202
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.017979852593086952
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.014066447403272783
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.01349724917787265
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000004
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.12488926591675897
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.08406046742107161
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.06430876075375756
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.021569583916710537
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.014066447403272783
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0025538829931845614
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 4",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 1.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.10355632160165408
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.06430876075375756
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.02624438633537202
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.014482283159691417
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.011725000181709532
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 5",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.10355632160165408
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.08406046742107161
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.07723983111465658
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.05042488844126454
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.017979852593086952
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 6",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.05042488844126454
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.021569583916710537
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.014482283159691417
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.01349724917787265
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.012795120884103492
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0021887873527123127
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 7",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.12488926591675897
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.07723983111465658
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.035168019110867574
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.012795120884103492
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.011725000181709532
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 8",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.907565743478425
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0026269973197130965
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.002251449469040589
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 29

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr2523eh'
B_doc_name = 'BILLS-117hr2523ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_tfidf_vectorized_transformation(A_doc, doc_tfidf_vectorizer)
B_doc_vectorized = document_tfidf_vectorized_transformation(B_doc, doc_tfidf_vectorizer)

A_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(A_section_doc, sec_tfidf_vectorizer)
B_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(B_section_doc, sec_tfidf_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr2523eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr2523ih",
#           "DOCUMENT SIMILARITY SCORE: 0.9753038133066074",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999998
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.919115805927868
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.028694212756616128
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.022020982490553793
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.021963374936576525
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.016072476395983245
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.010943510449786134
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.008565327897293239
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0010360868466060035
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999962
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.03315294267950948
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.022552312401849777
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.01838997506184354
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.010010353054877059
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.006841775212141577
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 4",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.8638269732409071
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.24248221262661807
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.1347550005217007
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.06413533452556713
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.01838997506184354
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.018217090065456642
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 5",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999997
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.8638269732409071
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.024131683521196177
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.022552312401849777
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.018490657429752103
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.01366819274893785
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.00193119072534939
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 6",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999999
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.27841836994274194
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.24248221262661807
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.14703732811951725
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.024131683521196177
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.006028998203869053
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 7",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999996
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.14703732811951725
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.1105637113220718
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.06413533452556713
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.010405277928754812
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.006841775212141577
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.00193119072534939
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 8",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999999
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.27841836994274194
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.1347550005217007
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.1105637113220718
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.03315294267950948
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.014632108244467304
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.01366819274893785
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 9",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0010150726450567475
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 30

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr3007ih'
B_doc_name = 'BILLS-117hr3007rh'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_tfidf_vectorized_transformation(A_doc, doc_tfidf_vectorizer)
B_doc_vectorized = document_tfidf_vectorized_transformation(B_doc, doc_tfidf_vectorizer)

A_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(A_section_doc, sec_tfidf_vectorizer)
B_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(B_section_doc, sec_tfidf_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr3007ih",
#           "MATCHED DOCUMENT ID: BILLS-117hr3007rh",
#           "DOCUMENT SIMILARITY SCORE: 0.9670147514339097",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr3007rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999999
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr3007rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr3007rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.9668822467123528
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr3007rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 31

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117s658rfh'
B_doc_name = 'BILLS-117s658rs'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_tfidf_vectorized_transformation(A_doc, doc_tfidf_vectorizer)
B_doc_vectorized = document_tfidf_vectorized_transformation(B_doc, doc_tfidf_vectorizer)

A_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(A_section_doc, sec_tfidf_vectorizer)
B_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(B_section_doc, sec_tfidf_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117s658rfh",
#           "MATCHED DOCUMENT ID: BILLS-117s658rs",
#           "DOCUMENT SIMILARITY SCORE: 1.0000000000000009",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117s658rs",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117s658rs",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117s658rs",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117s658rs",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117s658rs",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000013
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117s658rs",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.04284120131024222
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117s658rs",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117s658rs",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117s658rs",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000013
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117s658rs",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.04284120131024222
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117s658rs",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117s658rs",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 4",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117s658rs",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 1.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117s658rs",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117s658rs",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117s658rs",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 32

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117sjres13is'
B_doc_name = 'BILLS-117sjres13es'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_tfidf_vectorized_transformation(A_doc, doc_tfidf_vectorizer)
B_doc_vectorized = document_tfidf_vectorized_transformation(B_doc, doc_tfidf_vectorizer)

A_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(A_section_doc, sec_tfidf_vectorizer)
B_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(B_section_doc, sec_tfidf_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117sjres13is",
#           "MATCHED DOCUMENT ID: BILLS-117sjres13es",
#           "DOCUMENT SIMILARITY SCORE: 1.0",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117sjres13es",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000004
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 33

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117sres107is'
B_doc_name = 'BILLS-117sres107rs'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_tfidf_vectorized_transformation(A_doc, doc_tfidf_vectorizer)
B_doc_vectorized = document_tfidf_vectorized_transformation(B_doc, doc_tfidf_vectorizer)

A_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(A_section_doc, sec_tfidf_vectorizer)
B_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(B_section_doc, sec_tfidf_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117sres107is",
#           "MATCHED DOCUMENT ID: BILLS-117sres107rs",
#           "DOCUMENT SIMILARITY SCORE: 1.000000000000003",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117sres107rs",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000027
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 34

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117sres120is'
B_doc_name = 'BILLS-117sres120ats'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_tfidf_vectorized_transformation(A_doc, doc_tfidf_vectorizer)
B_doc_vectorized = document_tfidf_vectorized_transformation(B_doc, doc_tfidf_vectorizer)

A_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(A_section_doc, sec_tfidf_vectorizer)
B_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(B_section_doc, sec_tfidf_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117sres120is",
#           "MATCHED DOCUMENT ID: BILLS-117sres120ats",
#           "DOCUMENT SIMILARITY SCORE: 1.0000000000000007",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117sres120ats",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000038
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 35

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117sres81ats'
B_doc_name = 'BILLS-117sres81is'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_tfidf_vectorized_transformation(A_doc, doc_tfidf_vectorizer)
B_doc_vectorized = document_tfidf_vectorized_transformation(B_doc, doc_tfidf_vectorizer)

A_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(A_section_doc, sec_tfidf_vectorizer)
B_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(B_section_doc, sec_tfidf_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117sres81ats",
#           "MATCHED DOCUMENT ID: BILLS-117sres81is",
#           "DOCUMENT SIMILARITY SCORE: 1.0000000000000004",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117sres81is",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000013
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 36

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117sres37is'
B_doc_name = 'BILLS-117sres37rs'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_tfidf_vectorized_transformation(A_doc, doc_tfidf_vectorizer)
B_doc_vectorized = document_tfidf_vectorized_transformation(B_doc, doc_tfidf_vectorizer)

A_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(A_section_doc, sec_tfidf_vectorizer)
B_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(B_section_doc, sec_tfidf_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117sres37is",
#           "MATCHED DOCUMENT ID: BILLS-117sres37rs",
#           "DOCUMENT SIMILARITY SCORE: 0.9869431500006636",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117sres37rs",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.000000000000001
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117sres37rs",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.9548968217785122
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 37

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117sres22is'
B_doc_name = 'BILLS-117sres22rs'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_tfidf_vectorized_transformation(A_doc, doc_tfidf_vectorizer)
B_doc_vectorized = document_tfidf_vectorized_transformation(B_doc, doc_tfidf_vectorizer)

A_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(A_section_doc, sec_tfidf_vectorizer)
B_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(B_section_doc, sec_tfidf_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117sres22is",
#           "MATCHED DOCUMENT ID: BILLS-117sres22rs",
#           "DOCUMENT SIMILARITY SCORE: 1.0000000000000016",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117sres22rs",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.000000000000007
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 38

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117s1910es'
B_doc_name = 'BILLS-117s1910is'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_tfidf_vectorized_transformation(A_doc, doc_tfidf_vectorizer)
B_doc_vectorized = document_tfidf_vectorized_transformation(B_doc, doc_tfidf_vectorizer)

A_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(A_section_doc, sec_tfidf_vectorizer)
B_section_doc_vectorized = section_doc_tfidf_vectorized_transformation(B_section_doc, sec_tfidf_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117s1910es",
#           "MATCHED DOCUMENT ID: BILLS-117s1910is",
#           "DOCUMENT SIMILARITY SCORE: 1.0",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117s1910is",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117s1910is",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117s1910is",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 1.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117s1910is",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]
