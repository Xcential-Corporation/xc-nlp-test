# %%
import json
import time
import pickle
import re, string
import os
from os import path, listdir
from pathlib import Path
from os.path import isfile, join
from types import new_class
from typing import List
from lxml import etree 
from contextlib import ExitStack
import sklearn.feature_extraction.text
from nltk.tokenize import PunktSentenceTokenizer, RegexpTokenizer, TreebankWordTokenizer
from sklearn.feature_extraction.text import CountVectorizer, HashingVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.spatial.distance import cosine
from sklearn.metrics.pairwise import cosine_similarity

# Among the larger bills is samples/congress/116/BILLS-116s1790enr.xml (~ 10MB)

PATH_116_USLM = 'data/samples/congress/116/uslm'
PATH_116_USLM_TRAIN = 'data/samples/congress/116/train'
PATH_116_TEXT = 'data/samples/congress/116/txt'

BILLS_SAMPLE = [f'BILLS-116hr{number}ih.xml' for number in range(100, 300)]
BIG_BILLS = ['BILLS-116s1790enr.xml', 'BILLS-116hjres31enr.xml']
BIG_BILLS_PATHS = [path.join(PATH_116_USLM, bill) for bill in (BIG_BILLS + BILLS_SAMPLE)]

SAMPLE_BILL_PATHS_TRAIN = [join(PATH_116_USLM_TRAIN, f) for f in listdir(PATH_116_USLM) if isfile(join(PATH_116_USLM_TRAIN, f))]
SAMPLE_BILL_PATHS = [join(PATH_116_USLM, f) for f in listdir(PATH_116_USLM) if isfile(join(PATH_116_USLM, f))]


def getEnum(section) -> str:
  enumpath = section.xpath('enum')  
  if len(enumpath) > 0:
    return enumpath[0].text
  return ''

def getHeader(section) -> str:
  headerpath = section.xpath('header')  
  if len(headerpath) > 0:
    return headerpath[0].text
  return ''

def text_to_vect(txt: str , ngram_size: int = 4):
    """
    Gets ngrams from text
    """
    # See https://stackoverflow.com/a/32128803/628748
    tokenizer = PunktSentenceTokenizer()
    sentences = tokenizer.tokenize(txt)
    #vect = sklearn.feature_extraction.text.CountVectorizer(ngram_range=(ngram_size,ngram_size),
    #    tokenizer=TreebankWordTokenizer().tokenize, lowercase=True)
    vect = sklearn.feature_extraction.text.CountVectorizer(ngram_range=(ngram_size,ngram_size),
        tokenizer=RegexpTokenizer(r"\w+").tokenize, lowercase=True)
    vect.fit(sentences)
    # ngrams = vect.get_feature_names_out()
    # print('{1}-grams: {0}'.format(ngrams, ngram_size))
    #print(vect.vocabulary_)
    return vect # list of text documents

def xml_to_sections(xml_path: str):
    """
    Parses the xml file into sections 
    """
    try:
        billTree = etree.parse(xml_path)
    except:
        raise Exception('Could not parse bill')
    sections = billTree.xpath('//section')
    if len(sections) == 0:
        return []
    return [{
            'section_number': getEnum(section) ,
            'section_header':  getHeader(section),
            'section_text': etree.tostring(section, method="text", encoding="unicode"),
            'section_xml': etree.tostring(section, method="xml", encoding="unicode")
        } if (section.xpath('header') and len(section.xpath('header')) > 0  and section.xpath('enum') and len(section.xpath('enum'))>0) else
        {
            'section_number': '',
            'section_header': '', 
            'section_text': etree.tostring(section, method="text", encoding="unicode"),
            'section_xml': etree.tostring(section, method="xml", encoding="unicode")
        } 
        for section in sections ]

def xml_to_text(xml_path: str) -> str:
    """
    Parses the xml file and returns the text of the body element, if any
    """
    try:
        billTree = etree.parse(xml_path)
    except:
        raise Exception('Could not parse bill')
    parse_text =  etree.tostring(billTree, method="text", encoding="unicode")
    
    return parse_text
    bodies = billTree.xpath('//body')
    
    if len(sections) == 0:
        return '' 
    return etree.tostring(bodies[0], method="text", encoding="unicode"),

def xml_to_vect(xml_paths: List[str], ngram_size: int = 4):
    """
    Parses the xml file and returns the text of the body element, if any
    """
    total_str = '\n'.join([xml_to_text(xml_path) for xml_path in xml_paths])
    return text_to_vect(total_str, ngram_size=ngram_size)

    # to get the vocab dict: vect.vocabulary_

def combine_vocabs(vocabs: List[CountVectorizer]):
    """
    Combines one or more vocabs into one
    """
    vocab_keys = list(set([list(v.vocabulary_.keys()) for v in vocabs]))
    vocab = {vocab_key: str(i) for i, vocab_key in enumerate(vocab_keys)}
    return vocab

def get_combined_vocabs(xml_paths: List[str] = SAMPLE_BILL_PATHS, ngram_size: int = 4):
    """
    Gets the combined vocabulary of all the xml files
    """
    return xml_to_vect(xml_paths, ngram_size=ngram_size)

def getSampleText():
    return xml_to_text(BIG_BILLS_PATHS[0])

def transform_text(text: str, vocab: dict, ngram_size: int = 4):
    """
    Transforms text into a vector using the vocab
    """
    return CountVectorizer(vocabulary=vocab).fit_transform([text])

def train_count_vectorizer(train_data: List[str], ngram_size: int = 4):
    """
    Trains a count vectorizer on the training data
    """
    vectorizer = CountVectorizer(ngram_range=(ngram_size,ngram_size), preprocessor=xml_to_text, tokenizer=RegexpTokenizer(r"\w+").tokenize, lowercase=True)
    with ExitStack() as stack:
        files = [
            stack.enter_context(open(filename))
            for filename in train_data 
        ]
        X = vectorizer.fit_transform(files)
    return vectorizer, X 

def train_hashing_vectorizer(train_data: List[str], ngram_size: int = 4):
    """
    Trains a hashing vectorizer on the training data
    """
    vectorizer = HashingVectorizer(ngram_range=(ngram_size,ngram_size), preprocessor=xml_to_text, tokenizer=RegexpTokenizer(r"\w+").tokenize, lowercase=True)
    with ExitStack() as stack:
        files = [
            stack.enter_context(open(filename))
            for filename in train_data 
        ]
        X = vectorizer.fit_transform(files)
    return vectorizer, X

def test_hashing_vectorizer(vectorizer: HashingVectorizer, test_data: List[str]):
    return vectorizer.transform(test_data)

# TODO: Add a function to parse the bill (text) into paragraphs 

# TODO: create a streaming hash vectorizer. See 
# https://scikit-learn.org/stable/auto_examples/applications/plot_out_of_core_classification.html#sphx-glr-auto-examples-applications-plot-out-of-core-classification-py

# %% [markdown]
# ### Utility function for Text Cleaning

# %%
#clean text 
def text_cleaning(text):
    text = str(text).lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    return text

# %% [markdown]
# # Data Loading & Data Pre-processing

# %%
#get all files into one list

doc_corpus_data=[]
section_corpus_data = []

#get sections file from the section text files folder into list
paragraph_text_files = [f for f in os.listdir(PATH_116_TEXT) if f.endswith('.txt')]

for i in range(0, len(paragraph_text_files)):
    para_text_file = paragraph_text_files[i]
    
    
    delimiter = "\n"
    with open(os.path.join(PATH_116_TEXT, para_text_file), "r", encoding='UTF-8') as f:
        doc_content = f.read() 
        
        doc_corpus_data.append([Path(para_text_file).stem[:-9], text_cleaning(doc_content)])
        
        #using the string methods we split it
        paragraphs = doc_content.split(delimiter)
        
    for j in range(len(paragraphs)):   
        #for now sentence id is sentence number in document
        #append file id and clean text
        section_corpus_data.append([Path(para_text_file).stem[:-9], j,  text_cleaning(paragraphs[j])])
    

#get only whole document content from doc_corpus_data list
only_doc_data = [row[1] for row in doc_corpus_data]

#get only section content from section_corpus_data list
only_section_data = [row[2] for row in section_corpus_data]


#get length of only_doc_data list
print(len(only_doc_data))

#get length of only_section_data list
print(len(only_section_data))
# Out:
# 239
# 12355

# %% [markdown]
# # NLP Modeling

# %% [markdown]
# ## Model Training

# %%
#record training time for both vectorizer
start = time.time()


# Vectorizer to convert a collection of raw documents to a matrix 
doc_count_vectorizer = CountVectorizer(ngram_range=(4,4), tokenizer=RegexpTokenizer(r"\w+").tokenize, lowercase=True)
#Fit count vectorize instance on document level corpus
cv_doc_matrix = doc_count_vectorizer.fit_transform(only_doc_data)

# Vectorizer to convert a collection of sections to a matrix 
sec_count_vectorizer = CountVectorizer(ngram_range=(4,4), tokenizer=RegexpTokenizer(r"\w+").tokenize, lowercase=True)
#Fit count vectorize instance on section level corpus
cv_section_matrix = sec_count_vectorizer.fit_transform(only_section_data)


done = time.time()
elapsed = done - start
print("Time took in training of both vectorizer(s) ", elapsed)
# Out:
# Time took in training of both vectorizer(s)  12.192900657653809

# %% [markdown]
# ## Model Saving & Loading

# %%
# save count vectorize instance for only_doc_data
pickle.dump(doc_count_vectorizer, open("doc_count_vectorizer.pickel", "wb"))
# load count vectorize instance for only_doc_data
doc_count_vectorizer = pickle.load(open("doc_count_vectorizer.pickel", "rb"))

#save count vectorize instance for only_section_data
pickle.dump(sec_count_vectorizer, open("sec_count_vectorizer.pickel", "wb"))
# load count vectorize instance for only_section_data
sec_count_vectorizer = pickle.load(open("sec_count_vectorizer.pickel", "rb"))

# %% [markdown]
# ## Pick any Document A to any Document B from list for measuring similarity score

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-116hr866enr'
B_doc_name = 'BILLS-116s2107enr'

A_doc = [i[1] for i in doc_corpus_data if A_doc_name ==i[0]][0]
B_doc = [i[1] for i in doc_corpus_data if B_doc_name ==i[0]][0]

A_section_doc = [i[2] for i in section_corpus_data if A_doc_name ==i[0]]
B_section_doc = [i[2] for i in section_corpus_data if B_doc_name ==i[0]]

# %% [markdown]
# ## Transform Document A & B into vectorized space to perform cosine similarity

# %%
A_doc_vectorized = doc_count_vectorizer.transform([A_doc])
B_doc_vectorized = doc_count_vectorizer.transform([B_doc])

A_section_doc_vectorized = sec_count_vectorizer.transform(A_section_doc)
B_section_doc_vectorized = sec_count_vectorizer.transform(B_section_doc)

# %% [markdown]
# ## Measure Document Similarity Score of any Document A to any Document B

# %%
#record time for computing similarity 
start = time.time()

doc_sim_score =  cosine_similarity(A_doc_vectorized, B_doc_vectorized)

done = time.time()
elapsed = done - start
print("Time took in computing document to document similarity (s) ", elapsed)
# Out:
# Time took in computing document to document similarity (s)  0.0070037841796875

# %%
print(doc_sim_score)
# Out:
# [[0.01597025]]

# %% [markdown]
# ## Measure Pairwise similraity between Sections of Document A & Sections of Document B

# %%
# record time for computing similarity 
start = time.time()

sec_doc_sim_score =  cosine_similarity(A_section_doc_vectorized, B_section_doc_vectorized)

done = time.time()
elapsed = done - start
print("Time took in computing section to section similarity of document A & document B(s) ", elapsed)
# Out:
# Time took in computing section to section similarity of document A & document B(s)  0.007002830505371094

# %% [markdown]
# ## Rendering results of similarity b/w Document A & Document B and their Sections

# %%
#create result list
res_list = []

#create empty list
temp=[]
temp.append("ORIGINAL DOCUMENT ID: " + A_doc_name)
temp.append("MATCHED DOCUMENT ID: " + B_doc_name)
temp.append("DOCUMENT SIMILARITY SCORE: " + str(doc_sim_score[0][0]))

for i in range(0, sec_doc_sim_score.shape[0]):    
    temp.append("ORIGINAL SENTENCE ID: " + str(i+1))
    for j in range(0, sec_doc_sim_score.shape[1]):
        temp.append({"MATCHED DOCUMENT ID":  B_doc_name, "MATCHED SENTENCE ID": j+1 , "SENTENCE SIMILARITY SCORE":  sec_doc_sim_score[i][j]})
        
    res_list.append(temp)

# %%
#print pretty json
r = json.dumps(res_list)
parsed = json.loads(r)
print(json.dumps(parsed, indent=5))
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-116hr866enr",
#           "MATCHED DOCUMENT ID: BILLS-116s2107enr",
#           "DOCUMENT SIMILARITY SCORE: 0.01597025441533637",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.4803844614152615
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.009770471482819749
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.027151777644900656
#           },
#           "ORIGINAL SENTENCE ID: 4",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 5",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ],
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-116hr866enr",
#           "MATCHED DOCUMENT ID: BILLS-116s2107enr",
#           "DOCUMENT SIMILARITY SCORE: 0.01597025441533637",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.4803844614152615
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.009770471482819749
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.027151777644900656
#           },
#           "ORIGINAL SENTENCE ID: 4",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 5",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ],
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-116hr866enr",
#           "MATCHED DOCUMENT ID: BILLS-116s2107enr",
#           "DOCUMENT SIMILARITY SCORE: 0.01597025441533637",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.4803844614152615
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.009770471482819749
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.027151777644900656
#           },
#           "ORIGINAL SENTENCE ID: 4",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 5",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ],
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-116hr866enr",
#           "MATCHED DOCUMENT ID: BILLS-116s2107enr",
#           "DOCUMENT SIMILARITY SCORE: 0.01597025441533637",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.4803844614152615
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.009770471482819749
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.027151777644900656
#           },
#           "ORIGINAL SENTENCE ID: 4",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 5",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ],
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-116hr866enr",
#           "MATCHED DOCUMENT ID: BILLS-116s2107enr",
#           "DOCUMENT SIMILARITY SCORE: 0.01597025441533637",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.4803844614152615
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.009770471482819749
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.027151777644900656
#           },
#           "ORIGINAL SENTENCE ID: 4",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 5",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Measure pairwise similarity between document A and all documents in the corpus

# %%
#record time for computing similarity 
start = time.time()

doc_to_corpus_sim_score =  cosine_similarity(A_doc_vectorized, cv_doc_matrix)

done = time.time()
elapsed = done - start
print("Time took in computing similarity of document A and all documents in the corpus  (s) ", elapsed)
# Out:
# Time took in computing similarity of document A and all documents in the corpus  (s)  0.20244097709655762

# %% [markdown]
# ## Rendering results of similarity b/w document A and all documents in the corpus

# %%
#create result list
res_list = []

#get document names list from main doc_corpus_data list
corpus_doc_name_only = [row[0] for row in doc_corpus_data]

for i in range(0, doc_to_corpus_sim_score.shape[0]):
    #create empty list
    temp=[]
    temp.append("ORIGINAL DOCUMENT ID: " + A_doc_name)
    for j in range(0, doc_to_corpus_sim_score.shape[1]):
        temp.append({"MATCHED DOCUMENT ID": corpus_doc_name_only[j] , "DOCUMENT SIMILARITY SCORE":  doc_to_corpus_sim_score[i][j]})
        
    res_list.append(temp)

# %%
#print pretty json
r = json.dumps(res_list)
parsed = json.loads(r)
print(json.dumps(parsed, indent=5))
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-116hr866enr",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hconres105enr",
#                "DOCUMENT SIMILARITY SCORE": 0.012605195009606678
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hconres106enr",
#                "DOCUMENT SIMILARITY SCORE": 0.014745497924853898
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hconres16enr",
#                "DOCUMENT SIMILARITY SCORE": 0.01690898948255138
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hconres19enr",
#                "DOCUMENT SIMILARITY SCORE": 0.02614916723506242
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hconres21enr",
#                "DOCUMENT SIMILARITY SCORE": 0.013500268742399507
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hconres31enr",
#                "DOCUMENT SIMILARITY SCORE": 0.014253842401696592
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hconres45enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hconres53enr",
#                "DOCUMENT SIMILARITY SCORE": 0.013211973557919487
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hconres57enr",
#                "DOCUMENT SIMILARITY SCORE": 0.013211973557919487
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hconres72enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hconres75enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hconres81enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hconres82enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hconres86enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hconres87enr",
#                "DOCUMENT SIMILARITY SCORE": 0.015291811482433203
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hconres91enr",
#                "DOCUMENT SIMILARITY SCORE": 0.011543975487848617
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hconres92enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hconres9enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hjres28enr",
#                "DOCUMENT SIMILARITY SCORE": 0.024795351508706775
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hjres31enr",
#                "DOCUMENT SIMILARITY SCORE": 0.02912714227103454
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hjres46enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hjres60enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hjres76enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hjres80enr",
#                "DOCUMENT SIMILARITY SCORE": 0.02489326557119076
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hjres87enr",
#                "DOCUMENT SIMILARITY SCORE": 0.012605195009606678
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hjres88enr",
#                "DOCUMENT SIMILARITY SCORE": 0.01244663278559538
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr1058enr",
#                "DOCUMENT SIMILARITY SCORE": 0.008504630969319164
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr1079enr",
#                "DOCUMENT SIMILARITY SCORE": 0.033855856867761054
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr1112enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr1113enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr1114enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr1115enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr1116enr",
#                "DOCUMENT SIMILARITY SCORE": 0.04097976810689927
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr1117enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr1118enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr1119enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr1120enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr1121enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr1122enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr1123enr",
#                "DOCUMENT SIMILARITY SCORE": 0.030610587559908902
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr1138enr",
#                "DOCUMENT SIMILARITY SCORE": 0.005831512394917471
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr1158enr",
#                "DOCUMENT SIMILARITY SCORE": 0.03291005341271655
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr1198enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr1200enr",
#                "DOCUMENT SIMILARITY SCORE": 0.016473929912828107
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr1222enr",
#                "DOCUMENT SIMILARITY SCORE": 0.023029906081715602
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr1250enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr1252enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr1253enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr1327enr",
#                "DOCUMENT SIMILARITY SCORE": 0.016008125595891917
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr1365enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr1396enr",
#                "DOCUMENT SIMILARITY SCORE": 0.01053941889503054
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr1424enr",
#                "DOCUMENT SIMILARITY SCORE": 0.06602384128262659
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr1449enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr150enr",
#                "DOCUMENT SIMILARITY SCORE": 0.037024104813259254
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr1526enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr1569enr",
#                "DOCUMENT SIMILARITY SCORE": 0.04919963600275949
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr1590enr",
#                "DOCUMENT SIMILARITY SCORE": 0.013183350157690501
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr1812enr",
#                "DOCUMENT SIMILARITY SCORE": 0.032570785898238565
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr1839enr",
#                "DOCUMENT SIMILARITY SCORE": 0.013849069750217772
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr1844enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr1865enr",
#                "DOCUMENT SIMILARITY SCORE": 0.06465254816247223
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr1952enr",
#                "DOCUMENT SIMILARITY SCORE": 0.03192065397152114
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr1957enr",
#                "DOCUMENT SIMILARITY SCORE": 0.02925425568566231
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr1972enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr2030enr",
#                "DOCUMENT SIMILARITY SCORE": 0.02769059702066665
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr2151enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr2157enr",
#                "DOCUMENT SIMILARITY SCORE": 0.005586169627459363
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr2196enr",
#                "DOCUMENT SIMILARITY SCORE": 0.04103533309174703
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr2325enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr2333enr",
#                "DOCUMENT SIMILARITY SCORE": 0.028784035902267944
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr2334enr",
#                "DOCUMENT SIMILARITY SCORE": 0.01345636531314919
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr2336enr",
#                "DOCUMENT SIMILARITY SCORE": 0.044754763264954055
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr2359enr",
#                "DOCUMENT SIMILARITY SCORE": 0.022415149392063214
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr2372enr",
#                "DOCUMENT SIMILARITY SCORE": 0.023181614447409897
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr2379enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0018764004933252694
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr2385enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0027523598916345624
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr2423enr",
#                "DOCUMENT SIMILARITY SCORE": 0.015389308375487864
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr2451enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr2476enr",
#                "DOCUMENT SIMILARITY SCORE": 0.018983056694270726
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr251enr",
#                "DOCUMENT SIMILARITY SCORE": 0.022118246887280847
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr259enr",
#                "DOCUMENT SIMILARITY SCORE": 0.02376789269468225
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr263enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr266enr",
#                "DOCUMENT SIMILARITY SCORE": 0.016021203732287242
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr2695enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr276enr",
#                "DOCUMENT SIMILARITY SCORE": 0.020730174621822067
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr2938enr",
#                "DOCUMENT SIMILARITY SCORE": 0.024739126221838968
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr2940enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr299enr",
#                "DOCUMENT SIMILARITY SCORE": 0.06103894564834963
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr3055enr",
#                "DOCUMENT SIMILARITY SCORE": 0.02213817254944414
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr3144enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr3151enr",
#                "DOCUMENT SIMILARITY SCORE": 0.07438089318174004
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr3196enr",
#                "DOCUMENT SIMILARITY SCORE": 0.007653932941055959
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr3245enr",
#                "DOCUMENT SIMILARITY SCORE": 0.019022455739564677
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr3253enr",
#                "DOCUMENT SIMILARITY SCORE": 0.007387162952652784
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr3304enr",
#                "DOCUMENT SIMILARITY SCORE": 0.014702570620012432
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr3305enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr3311enr",
#                "DOCUMENT SIMILARITY SCORE": 0.020938007403080897
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr3314enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr3399enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr3401enr",
#                "DOCUMENT SIMILARITY SCORE": 0.016758297907047994
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr3504enr",
#                "DOCUMENT SIMILARITY SCORE": 0.029866273420579216
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr3877enr",
#                "DOCUMENT SIMILARITY SCORE": 0.011778243050584197
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr3889enr",
#                "DOCUMENT SIMILARITY SCORE": 0.005484641711080482
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr4183enr",
#                "DOCUMENT SIMILARITY SCORE": 0.020554937542161433
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr4258enr",
#                "DOCUMENT SIMILARITY SCORE": 0.030803844559716555
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr4285enr",
#                "DOCUMENT SIMILARITY SCORE": 0.04481185044580477
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr430enr",
#                "DOCUMENT SIMILARITY SCORE": 0.018907792514410018
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr4334enr",
#                "DOCUMENT SIMILARITY SCORE": 0.025515689509918078
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr434enr",
#                "DOCUMENT SIMILARITY SCORE": 0.029291826208742103
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr4378enr",
#                "DOCUMENT SIMILARITY SCORE": 0.014868305556964412
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr4387enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0018785364080672268
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr439enr",
#                "DOCUMENT SIMILARITY SCORE": 0.050933862092816876
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr4566enr",
#                "DOCUMENT SIMILARITY SCORE": 0.012728175434121969
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr4771enr",
#                "DOCUMENT SIMILARITY SCORE": 0.04043825668218495
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr4779enr",
#                "DOCUMENT SIMILARITY SCORE": 0.012919587309269596
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr4803enr",
#                "DOCUMENT SIMILARITY SCORE": 0.008783191817834582
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr4920enr",
#                "DOCUMENT SIMILARITY SCORE": 0.051867827135560075
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr4998enr",
#                "DOCUMENT SIMILARITY SCORE": 0.021410184883380715
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr504enr",
#                "DOCUMENT SIMILARITY SCORE": 0.024357555832159684
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr5214enr",
#                "DOCUMENT SIMILARITY SCORE": 0.07071572924571595
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr5277enr",
#                "DOCUMENT SIMILARITY SCORE": 0.027128900610018727
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr5363enr",
#                "DOCUMENT SIMILARITY SCORE": 0.022844829548890715
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr540enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr5430enr",
#                "DOCUMENT SIMILARITY SCORE": 0.023123126333097637
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr559enr",
#                "DOCUMENT SIMILARITY SCORE": 0.028580944529914457
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr561enr",
#                "DOCUMENT SIMILARITY SCORE": 0.02752778091106078
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr5671enr",
#                "DOCUMENT SIMILARITY SCORE": 0.013149155819736726
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr583enr",
#                "DOCUMENT SIMILARITY SCORE": 0.014531166177102813
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr6074enr",
#                "DOCUMENT SIMILARITY SCORE": 0.009775605071860717
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr6168enr",
#                "DOCUMENT SIMILARITY SCORE": 0.016473929912828107
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr6201enr",
#                "DOCUMENT SIMILARITY SCORE": 0.04776510064174985
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr6322enr",
#                "DOCUMENT SIMILARITY SCORE": 0.035387560694724096
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr639enr",
#                "DOCUMENT SIMILARITY SCORE": 0.05042078003842671
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr7010enr",
#                "DOCUMENT SIMILARITY SCORE": 0.035187507830430925
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr724enr",
#                "DOCUMENT SIMILARITY SCORE": 0.03231060859457643
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr7440enr",
#                "DOCUMENT SIMILARITY SCORE": 0.005221845326920054
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr748enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0647733854151132
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr776enr",
#                "DOCUMENT SIMILARITY SCORE": 0.02174012933470892
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr777enr",
#                "DOCUMENT SIMILARITY SCORE": 0.015414451613906045
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr828enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr829enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr831enr",
#                "DOCUMENT SIMILARITY SCORE": 0.02808188051554612
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr8337enr",
#                "DOCUMENT SIMILARITY SCORE": 0.05453978333380857
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr866enr",
#                "DOCUMENT SIMILARITY SCORE": 0.999999999999992
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr886enr",
#                "DOCUMENT SIMILARITY SCORE": 0.01056131813475996
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr887enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr943enr",
#                "DOCUMENT SIMILARITY SCORE": 0.018830696199364946
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116hr991enr",
#                "DOCUMENT SIMILARITY SCORE": 0.009262888764543979
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s1196enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s1321enr",
#                "DOCUMENT SIMILARITY SCORE": 0.05091368627024165
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s1379enr",
#                "DOCUMENT SIMILARITY SCORE": 0.03166405193593683
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s1380enr",
#                "DOCUMENT SIMILARITY SCORE": 0.014266841804673507
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s1436enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0377556268730975
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s151enr",
#                "DOCUMENT SIMILARITY SCORE": 0.04665297501418864
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s153enr",
#                "DOCUMENT SIMILARITY SCORE": 0.02344518649235441
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s163enr",
#                "DOCUMENT SIMILARITY SCORE": 0.019778997871904746
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s1646enr",
#                "DOCUMENT SIMILARITY SCORE": 0.01345636531314919
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s1678enr",
#                "DOCUMENT SIMILARITY SCORE": 0.010820798986353946
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s1689enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0012878890140124246
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s1693enr",
#                "DOCUMENT SIMILARITY SCORE": 0.018011172597724404
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s1749enr",
#                "DOCUMENT SIMILARITY SCORE": 0.033786180200228624
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s1790enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0930978943423079
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s1822enr",
#                "DOCUMENT SIMILARITY SCORE": 0.005800217025607051
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s1838enr",
#                "DOCUMENT SIMILARITY SCORE": 0.010751262579304505
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2047enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s209enr",
#                "DOCUMENT SIMILARITY SCORE": 0.021670715394856935
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2107enr",
#                "DOCUMENT SIMILARITY SCORE": 0.01597025441533637
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2163enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0033654574568017957
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s216enr",
#                "DOCUMENT SIMILARITY SCORE": 0.005902923399108997
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2193enr",
#                "DOCUMENT SIMILARITY SCORE": 0.023870814591031138
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2249enr",
#                "DOCUMENT SIMILARITY SCORE": 0.007924952068218707
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s227enr",
#                "DOCUMENT SIMILARITY SCORE": 0.01882057918251961
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2330enr",
#                "DOCUMENT SIMILARITY SCORE": 0.06948191616493428
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s239enr",
#                "DOCUMENT SIMILARITY SCORE": 0.02014880409898174
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s24enr",
#                "DOCUMENT SIMILARITY SCORE": 0.02540005068883075
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s252enr",
#                "DOCUMENT SIMILARITY SCORE": 0.004522312380547717
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s256enr",
#                "DOCUMENT SIMILARITY SCORE": 0.01221145254204609
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2638enr",
#                "DOCUMENT SIMILARITY SCORE": 0.026509546451649026
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2661enr",
#                "DOCUMENT SIMILARITY SCORE": 0.02232093089027653
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2710enr",
#                "DOCUMENT SIMILARITY SCORE": 0.02722590524925563
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s2746enr",
#                "DOCUMENT SIMILARITY SCORE": 0.014895470486936275
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s294enr",
#                "DOCUMENT SIMILARITY SCORE": 0.006112113416597592
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s3051enr",
#                "DOCUMENT SIMILARITY SCORE": 0.012332086314154032
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s3084enr",
#                "DOCUMENT SIMILARITY SCORE": 0.04172120788800771
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s3105enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s3201enr",
#                "DOCUMENT SIMILARITY SCORE": 0.007719073970453315
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s3414enr",
#                "DOCUMENT SIMILARITY SCORE": 0.00814823384104427
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s3503enr",
#                "DOCUMENT SIMILARITY SCORE": 0.02566533256612854
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s3607enr",
#                "DOCUMENT SIMILARITY SCORE": 0.008179330592355165
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s3637enr",
#                "DOCUMENT SIMILARITY SCORE": 0.01842177551546797
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s3744enr",
#                "DOCUMENT SIMILARITY SCORE": 0.008071796578317827
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s3758enr",
#                "DOCUMENT SIMILARITY SCORE": 0.001220492758697588
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s375enr",
#                "DOCUMENT SIMILARITY SCORE": 0.010642024949651134
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s394enr",
#                "DOCUMENT SIMILARITY SCORE": 0.024885586019698064
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s4072enr",
#                "DOCUMENT SIMILARITY SCORE": 0.014372133578535829
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s4075enr",
#                "DOCUMENT SIMILARITY SCORE": 0.022724338472179834
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s4091enr",
#                "DOCUMENT SIMILARITY SCORE": 0.012505389836576562
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s4116enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s4148enr",
#                "DOCUMENT SIMILARITY SCORE": 0.006957879249892209
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s4209enr",
#                "DOCUMENT SIMILARITY SCORE": 0.011922828257456611
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s457enr",
#                "DOCUMENT SIMILARITY SCORE": 0.02276308417545992
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s4762enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s47enr",
#                "DOCUMENT SIMILARITY SCORE": 0.03740449225022983
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s483enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0018029402242156986
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s490enr",
#                "DOCUMENT SIMILARITY SCORE": 0.011927792999815215
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s49enr",
#                "DOCUMENT SIMILARITY SCORE": 0.005648490633519655
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s504enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0182489944489694
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s50enr",
#                "DOCUMENT SIMILARITY SCORE": 0.009237167091472208
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s693enr",
#                "DOCUMENT SIMILARITY SCORE": 0.05400107496959804
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s725enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s737enr",
#                "DOCUMENT SIMILARITY SCORE": 0.014278426736996292
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s743enr",
#                "DOCUMENT SIMILARITY SCORE": 0.01431297135441278
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s744enr",
#                "DOCUMENT SIMILARITY SCORE": 0.02425800390133142
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s760enr",
#                "DOCUMENT SIMILARITY SCORE": 0.03308078389502797
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s785enr",
#                "DOCUMENT SIMILARITY SCORE": 0.04169906559929819
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s832enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s862enr",
#                "DOCUMENT SIMILARITY SCORE": 0.01565522831225747
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s863enr",
#                "DOCUMENT SIMILARITY SCORE": 0.029812353484215327
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s881enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0072986719406062965
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s893enr",
#                "DOCUMENT SIMILARITY SCORE": 0.00691997055128461
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s982enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0074107670728727525
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116s998enr",
#                "DOCUMENT SIMILARITY SCORE": 0.00913723712907798
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116sconres14enr",
#                "DOCUMENT SIMILARITY SCORE": 0.013211973557919487
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116sconres27enr",
#                "DOCUMENT SIMILARITY SCORE": 0.014372133578535827
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116sconres38enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116sconres45enr",
#                "DOCUMENT SIMILARITY SCORE": 0.021326206831813074
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116sconres46enr",
#                "DOCUMENT SIMILARITY SCORE": 0.02484362790351277
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116sconres4enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116sconres6enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116sconres7enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116sjres36enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116sjres37enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116sjres38enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116sjres54enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116sjres65enr",
#                "DOCUMENT SIMILARITY SCORE": 0.012769975794374198
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116sjres66enr",
#                "DOCUMENT SIMILARITY SCORE": 0.013211973557919487
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116sjres67enr",
#                "DOCUMENT SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116sjres68enr",
#                "DOCUMENT SIMILARITY SCORE": 0.009419541351787781
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-116sjres7enr",
#                "DOCUMENT SIMILARITY SCORE": 0.01224081971190472
#           }
#      ]
# ]
