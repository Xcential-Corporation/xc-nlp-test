# %%
# python
import json
import time
import pickle
import re, string
import os
from os import path, listdir
from pathlib import Path
from os.path import isfile, join
from types import new_class
from typing import List
from lxml import etree 
from contextlib import ExitStack
import sklearn.feature_extraction.text
from nltk.tokenize import PunktSentenceTokenizer, RegexpTokenizer, TreebankWordTokenizer
from sklearn.feature_extraction.text import CountVectorizer, HashingVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.spatial.distance import cosine
from sklearn.metrics.pairwise import cosine_similarity

# Among the larger bills is samples/congress/116/BILLS-116s1790enr.xml (~ 10MB)

PATH_116_USLM = '/usr/local/share/xcential/public/data/116/uslm'
PATH_117_USLM = '/usr/local/share/xcential/public/data/117/uslm'
PATH_116_USLM_TRAIN = 'samples/congress/116/train'
PATH_116_TEXT = 'samples/congress/116/txt'

BILLS_SAMPLE = [f'BILLS-116hr{number}ih.xml' for number in range(100, 300)]
BIG_BILLS = ['BILLS-116s1790enr.xml', 'BILLS-116hjres31enr.xml']
BIG_BILLS_PATHS = [path.join(PATH_116_USLM, bill) for bill in (BIG_BILLS + BILLS_SAMPLE)]

SAMPLE_BILL_PATHS_TRAIN = [join(PATH_116_USLM_TRAIN, f) for f in listdir(PATH_116_USLM) if isfile(join(PATH_116_USLM_TRAIN, f))]
SAMPLE_BILL_PATHS = [join(PATH_117_USLM, f) for f in listdir(PATH_117_USLM) if isfile(join(PATH_117_USLM, f))]


NAMESPACES = {'uslm': 'http://xml.house.gov/schemas/uslm/1.0'}


def get_filepaths(dirpath: str, reMatch = r'.xml$') -> List[str]:
    return [join(dirpath, f) for f in listdir(dirpath) if (len(re.findall(reMatch, f)) > 0) and isfile(join(dirpath, f))]

def getEnum(section) -> str:
  enumpath = section.xpath('enum')  
  if len(enumpath) > 0:
    return enumpath[0].text
  return ''

def getHeader(section) -> str:
  headerpath = section.xpath('header')  
  if len(headerpath) > 0:
    return headerpath[0].text
  return ''

def text_to_vect(txt: str , ngram_size: int = 4):
    """
    Gets ngrams from text
    """
    # See https://stackoverflow.com/a/32128803/628748
    tokenizer = PunktSentenceTokenizer()
    sentences = tokenizer.tokenize(txt)
    #vect = sklearn.feature_extraction.text.CountVectorizer(ngram_range=(ngram_size,ngram_size),
    #    tokenizer=TreebankWordTokenizer().tokenize, lowercase=True)
    vect = sklearn.feature_extraction.text.CountVectorizer(ngram_range=(ngram_size,ngram_size),
        tokenizer=RegexpTokenizer(r"\w+").tokenize, lowercase=True)
    vect.fit(sentences)
    # ngrams = vect.get_feature_names_out()
    # print('{1}-grams: {0}'.format(ngrams, ngram_size))
    #print(vect.vocabulary_)
    return vect # list of text documents

def xml_to_sections(xml_path: str):
    """
    Parses the xml file into sections 
    """
    try:
        billTree = etree.parse(xml_path)
    except:
        raise Exception('Could not parse bill')
    sections = billTree.xpath('//uslm:section', namespaces=NAMESPACES)
    if len(sections) == 0:
        print('No sections found')
        return []
    return [{
            'section_number': getEnum(section) ,
            'section_header':  getHeader(section),
            'section_text': etree.tostring(section, method="text", encoding="unicode"),
            'section_xml': etree.tostring(section, method="xml", encoding="unicode")
        } if (section.xpath('header') and len(section.xpath('header')) > 0  and section.xpath('enum') and len(section.xpath('enum'))>0) else
        {
            'section_number': '',
            'section_header': '', 
            'section_text': etree.tostring(section, method="text", encoding="unicode"),
            'section_xml': etree.tostring(section, method="xml", encoding="unicode")
        } 
        for section in sections ]

def xml_to_text(xml_path: str, level: str = 'section', separator: str = '\n*****\n') -> str:
    """
    Parses the xml file and returns the text of the body element, if any
    """
    try:
        billTree = etree.parse(xml_path)
    except:
        raise Exception('Could not parse bill')
    #return etree.tostring(billTree, method="text", encoding="unicode")
    # Use 'body' for level to get the whole body element
    sections = billTree.xpath('//uslm:'+level, namespaces=NAMESPACES)
    if len(sections) == 0:
        print('No sections found')
        return '' 
    return separator.join([etree.tostring(section, method="text", encoding="unicode") for section in sections])

def xml_to_vect(xml_paths: List[str], ngram_size: int = 4):
    """
    Parses the xml file and returns the text of the body element, if any
    """
    total_str = '\n'.join([xml_to_text(xml_path) for xml_path in xml_paths])
    return text_to_vect(total_str, ngram_size=ngram_size)

    # to get the vocab dict: vect.vocabulary_

def combine_vocabs(vocabs: List[CountVectorizer]):
    """
    Combines one or more vocabs into one
    """
    vocab_keys = list(set([list(v.vocabulary_.keys()) for v in vocabs]))
    vocab = {vocab_key: str(i) for i, vocab_key in enumerate(vocab_keys)}
    return vocab

def get_combined_vocabs(xml_paths: List[str] = SAMPLE_BILL_PATHS, ngram_size: int = 4):
    """
    Gets the combined vocabulary of all the xml files
    """
    return xml_to_vect(xml_paths, ngram_size=ngram_size)

def getSampleText(level = 'body'):
    return xml_to_text(BIG_BILLS_PATHS[0])

def transform_text(text: str, vocab: dict, ngram_size: int = 4):
    """
    Transforms text into a vector using the vocab
    """
    return CountVectorizer(vocabulary=vocab).fit_transform([text])

def train_count_vectorizer(train_data: List[str], ngram_size: int = 4):
    """
    Trains a count vectorizer on the training data
    """
    vectorizer = CountVectorizer(ngram_range=(ngram_size,ngram_size), preprocessor=xml_to_text, tokenizer=RegexpTokenizer(r"\w+").tokenize, lowercase=True)
    with ExitStack() as stack:
        files = [
            stack.enter_context(open(filename))
            for filename in train_data 
        ]
        X = vectorizer.fit_transform(files)
    return vectorizer, X 

def train_hashing_vectorizer(train_data: List[str], ngram_size: int = 4):
    """
    Trains a hashing vectorizer on the training data
    """
    vectorizer = HashingVectorizer(ngram_range=(ngram_size,ngram_size), preprocessor=xml_to_text, tokenizer=RegexpTokenizer(r"\w+").tokenize, lowercase=True)
    with ExitStack() as stack:
        files = [
            stack.enter_context(open(filename))
            for filename in train_data 
        ]
        X = vectorizer.fit_transform(files)
    return vectorizer, X

def test_hashing_vectorizer(vectorizer: HashingVectorizer, test_data: List[str]):
    return vectorizer.transform(test_data)

def xml_samples_to_text(dirpath: str, level: str = 'section', separator: str = '\n*****\n'):
    """
    Converts xml files in a directory to txt files
    """
    xfiles = get_filepaths(dirpath)
    for xfile in xfiles:
        with open(xfile.replace('.xml', f'-{level}s.txt'), 'w') as f:
            f.write(xml_to_text(xfile, level=level, separator=separator))

# TODO: Add a function to parse the bill (text) into paragraphs 

# TODO: create a streaming hash vectorizer. See 
# https://scikit-learn.org/stable/auto_examples/applications/plot_out_of_core_classification.html#sphx-glr-auto-examples-applications-plot-out-of-core-classification-py

# %% [markdown]
# ### Utility function for Text Cleaning

# %%
#clean text 
def text_cleaning(text):
    text = str(text).lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    return text

# %% [markdown]
# # Data Loading & Data Pre-processing

# %%
#xml document and section level parsing

#record training time for both vectorizer
start = time.time()


doc_corpus_data=[]
section_corpus_data = []

#get all xml files from data directory for parsing
bill_files = [f for f in os.listdir(PATH_117_USLM) if f.endswith('.xml')]

#iterate over all bill files
for i in range(0, len(bill_files)):
    
    #indexing bill document file
    bill_doc_file = bill_files[i]
    
    #parse xml into sections
    secs = xml_to_sections(os.path.join(PATH_117_USLM, bill_doc_file))
    
    #check  of sections should be 1 or more than 1
    if(len(secs)>0):  
        
        #intialize string variable for document content
        doc_content = ""
        
        #iterate over all parse sections text of bill doc file
        for s_number, section in enumerate(secs):  
            
            #text cleaning applied on each section text
            sec_text = text_cleaning(section['section_text'])
            
            #concatenate section text to doc content 
            doc_content = doc_content + sec_text + " "
            
             #for now sentence id is sentence number in document
            section_corpus_data.append([Path(bill_doc_file).stem[:], s_number, sec_text ])

        doc_corpus_data.append([Path(bill_doc_file).stem[:], doc_content])
    

#get only whole document content from doc_corpus_data list
only_doc_data = [row[1] for row in doc_corpus_data]

#get only section content from section_corpus_data list
only_section_data = [row[2] for row in section_corpus_data]


#get length of only_doc_data list
print(len(only_doc_data))

#get length of only_section_data list
print(len(only_section_data))

done = time.time()
elapsed = done - start
print('Time took in ETL with {} xml data files is {}'.format(len(only_doc_data), elapsed))
# Out:
# No sections found
# No sections found
# 9166
# 55007
# Time took in ETL with 9166 xml data files is 56.63388204574585

# %% [markdown]
# # NLP Modeling

# %% [markdown]
# ## Model Training

# %%
#record training time for both vectorizer
start = time.time()


# Vectorizer to convert a collection of raw documents to a matrix 
doc_hash_vectorizer = HashingVectorizer(ngram_range=(4,4), tokenizer=RegexpTokenizer(r"\w+").tokenize, lowercase=True)
#Fit hash vectorize instance on document level corpus
hv_doc_matrix = doc_hash_vectorizer.fit_transform(only_doc_data)

# Vectorizer to convert a collection of sections to a matrix 
sec_hash_vectorizer = HashingVectorizer(ngram_range=(4,4), tokenizer=RegexpTokenizer(r"\w+").tokenize, lowercase=True)
#Fit hash vectorize instance on section level corpus
hv_section_matrix = sec_hash_vectorizer.fit_transform(only_section_data)


done = time.time()
elapsed = done - start
print("Time took in training of both vectorizer(s) ", elapsed)
# Out:
# /Users/arihershowitz/.pyenv/versions/3.8.10/envs/scikit/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:516: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Time took in training of both vectorizer(s)  38.91292405128479

# %% [markdown]
# ## Model Saving & Loading

# %%
# save hash vectorize instance for only_doc_data
pickle.dump(doc_hash_vectorizer, open("doc_hash_vectorizer.pickle", "wb"))
# load hash vectorize instance for only_doc_data
doc_hash_vectorizer = pickle.load(open("doc_hash_vectorizer.pickle", "rb"))

#save hash vectorize instance for only_section_data
pickle.dump(sec_hash_vectorizer, open("sec_hash_vectorizer.pickle", "wb"))
# load hash vectorize instance for only_section_data
sec_hash_vectorizer = pickle.load(open("sec_hash_vectorizer.pickle", "rb"))

# %% [markdown]
# ## Get Document and Sections Text from XML File

# %%
#et document and section text from xml file for testing purpose 
def get_document_and_section_from_xml_file(file_path):
    
    #create empty t_section_data list
    t_section_data=[] 
    
    #get sections fron xml file
    t_secs = xml_to_sections(file_path)
    
    #check if length of section is more than 0  
    if(len(t_secs)>0): 
        
            #intialize string variable for document content
            t_doc_content = ""

            #iterate over all parse sections text of bill doc file
            for s_number, section in enumerate(t_secs):  

                #text cleaning applied on each section text
                sec_text = text_cleaning(section['section_text'])

                #concatenate section text to doc content 
                t_doc_content = t_doc_content + sec_text + " "

                 #for now sentence id is sentence number in document
                t_section_data.append(sec_text)

    return t_doc_content, t_section_data

# %%
#choose document A file name & document B file name 
A_doc_name = 'BILLS-117hr200ih'
B_doc_name = 'BILLS-117hr201ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %% [markdown]
# ## Transform Document A & B into vectorized space to perform cosine similarity

# %%
def document_hash_vectorized_transformation(document, doc_hash_vectorizer):
    
    doc_vectorized = doc_hash_vectorizer.transform([document])
    return doc_vectorized

def section_doc_hash_vectorized_transformation(section_doc, sec_hash_vectorizer):
    
    section_doc_vectorized = sec_hash_vectorizer.transform(section_doc)
    return section_doc_vectorized

# %%
#transform document A content and document B content
A_doc_vectorized = document_hash_vectorized_transformation(A_doc, doc_hash_vectorizer)
B_doc_vectorized = document_hash_vectorized_transformation(B_doc, doc_hash_vectorizer)

#transform document A section content and  document B section content
A_section_doc_vectorized = section_doc_hash_vectorized_transformation(A_section_doc, sec_hash_vectorizer)
B_section_doc_vectorized = section_doc_hash_vectorized_transformation(B_section_doc, sec_hash_vectorizer)

# %% [markdown]
# ## Calculate Cosine Similarity

# %%
def cosine_pairwise_sim(a_vectorized, b_vectorized):
    
    #record time for computing similarity 
    start = time.time()

    sim_score =  cosine_similarity(a_vectorized, b_vectorized)

    done = time.time()
    elapsed = done - start
    return elapsed, sim_score

# %% [markdown]
# ## Measure Document Similarity Score of any Document A to any Document B

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)

# %% [markdown]
# ## Measure Pairwise similraity between Sections of Document A & Sections of Document B

# %%
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

# %%
elapsed
# Out:
# 0.003020048141479492

# %% [markdown]
# ## Rendering results of similarity b/w Document A & Document B and their Sections

# %%
def create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score):
    
    #create result list
    res_list = []

    #create empty list
    temp=[]
    temp.append("ORIGINAL DOCUMENT ID: " + A_doc_name)
    temp.append("MATCHED DOCUMENT ID: " + B_doc_name)
    temp.append("DOCUMENT SIMILARITY SCORE: " + str(doc_sim_score[0][0]))

    #iterate over sec_doc_sim_score list 
    for i, section_score_list in enumerate(sec_doc_sim_score):
        
        #add original document sentence id number
        temp.append("ORIGINAL SENTENCE ID: " + str(i+1))
           
        #sort similarity score of sections list
        section_score_list = list(enumerate(section_score_list))
        sorted_section_score_list = sorted(section_score_list, key=lambda x: x[1], reverse=True)
        
        #iterate over section level score only 
        for j, sim_score in sorted_section_score_list:
            temp.append({"MATCHED DOCUMENT ID":  B_doc_name, "MATCHED SENTENCE ID": j+1 , "SENTENCE SIMILARITY SCORE":  sim_score})

    res_list.append(temp)
        
    #return pretty json
    r = json.dumps(res_list)
    parsed = json.loads(r)
    return json.dumps(parsed, indent=5)

# %%
#put document A file name & document B file name
A_doc_name = 'BILLS-117hr200ih'
B_doc_name = 'BILLS-117hr201ih'

#get json response of newly computed similarity score of document A and document B
response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr200ih",
#           "MATCHED DOCUMENT ID: BILLS-117hr201ih",
#           "DOCUMENT SIMILARITY SCORE: 0.721456637430483",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr201ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.521749194749951
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr201ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr201ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.7517730496453908
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr201ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# # Testing

# %% [markdown]
# ## Case # 1

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hjres27enr'
B_doc_name = 'BILLS-117hjres27ih'


A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_hash_vectorized_transformation(A_doc, doc_hash_vectorizer)
B_doc_vectorized = document_hash_vectorized_transformation(B_doc, doc_hash_vectorizer)

A_section_doc_vectorized = section_doc_hash_vectorized_transformation(A_section_doc, sec_hash_vectorizer)
B_section_doc_vectorized = section_doc_hash_vectorized_transformation(B_section_doc, sec_hash_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hjres27enr",
#           "MATCHED DOCUMENT ID: BILLS-117hjres27ih",
#           "DOCUMENT SIMILARITY SCORE: 1.000000000000003",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hjres27ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.000000000000003
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 2

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr293eh'
B_doc_name = 'BILLS-117hr293ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_hash_vectorized_transformation(A_doc, doc_hash_vectorizer)
B_doc_vectorized = document_hash_vectorized_transformation(B_doc, doc_hash_vectorizer)

A_section_doc_vectorized = section_doc_hash_vectorized_transformation(A_section_doc, sec_hash_vectorizer)
B_section_doc_vectorized = section_doc_hash_vectorized_transformation(B_section_doc, sec_hash_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr293eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr293ih",
#           "DOCUMENT SIMILARITY SCORE: 1.0000000000000002",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr293ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr293ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr293ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr293ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999998
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr293ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr293ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr293ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr293ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr293ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 3

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr335enr'
B_doc_name = 'BILLS-117hr335ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_hash_vectorized_transformation(A_doc, doc_hash_vectorizer)
B_doc_vectorized = document_hash_vectorized_transformation(B_doc, doc_hash_vectorizer)

A_section_doc_vectorized = section_doc_hash_vectorized_transformation(A_section_doc, sec_hash_vectorizer)
B_section_doc_vectorized = section_doc_hash_vectorized_transformation(B_section_doc, sec_hash_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr335enr",
#           "MATCHED DOCUMENT ID: BILLS-117hr335ih",
#           "DOCUMENT SIMILARITY SCORE: 0.9999999999999997",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr335ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999997
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 4

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr335enr'
B_doc_name = 'BILLS-117hr335ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_hash_vectorized_transformation(A_doc, doc_hash_vectorizer)
B_doc_vectorized = document_hash_vectorized_transformation(B_doc, doc_hash_vectorizer)

A_section_doc_vectorized = section_doc_hash_vectorized_transformation(A_section_doc, sec_hash_vectorizer)
B_section_doc_vectorized = section_doc_hash_vectorized_transformation(B_section_doc, sec_hash_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr335enr",
#           "MATCHED DOCUMENT ID: BILLS-117hr335ih",
#           "DOCUMENT SIMILARITY SCORE: 0.9999999999999997",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr335ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999997
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 5

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr1195eh'
B_doc_name = 'BILLS-117hr1195rh'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_hash_vectorized_transformation(A_doc, doc_hash_vectorizer)
B_doc_vectorized = document_hash_vectorized_transformation(B_doc, doc_hash_vectorizer)

A_section_doc_vectorized = section_doc_hash_vectorized_transformation(A_section_doc, sec_hash_vectorizer)
B_section_doc_vectorized = section_doc_hash_vectorized_transformation(B_section_doc, sec_hash_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr1195eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr1195rh",
#           "DOCUMENT SIMILARITY SCORE: 0.9835438921537075",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.16805349924838137
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.03724711252952215
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.033633639699815615
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000004
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.12565388414768014
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.033633639699815615
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0028218879214653805
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.9697720309975824
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.16540561450194455
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.12307945235349514
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.12031536905592868
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.05647831063847004
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.03509484917006726
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0017777672428919743
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 4",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.9914367969987856
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.11432245256353102
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0570966690972205
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.04187089067129492
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.01541267072458278
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.008432290716936044
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 5",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.9761296015870492
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.12411243857091478
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.11296444775037574
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.02239055377599458
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.015360450318182475
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.010208249115625356
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0027740558477878704
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 6",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.8876253645985963
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.12585634889349645
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.026743109337025124
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.008508312214487779
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.006944611899489514
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 7",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999714
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.042086907018159675
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.015625305184721997
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.00188679245283016
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0016371019870343839
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 8",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999992
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.16805349924838137
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.12565388414768014
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.11787134306647595
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.03263956049169339
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.02277662625494185
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.015492186320548744
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0016371019870343839
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 6

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr1205eh'
B_doc_name = 'BILLS-117hr1205ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_hash_vectorized_transformation(A_doc, doc_hash_vectorizer)
B_doc_vectorized = document_hash_vectorized_transformation(B_doc, doc_hash_vectorizer)

A_section_doc_vectorized = section_doc_hash_vectorized_transformation(A_section_doc, sec_hash_vectorizer)
B_section_doc_vectorized = section_doc_hash_vectorized_transformation(B_section_doc, sec_hash_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr1205eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr1205ih",
#           "DOCUMENT SIMILARITY SCORE: 0.9999999999999984",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1205ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1205ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1205ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1205ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000024
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1205ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.9734008528351867
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1205ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1205ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999956
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1205ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.9734008528351867
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1205ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 7

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr1251eh'
B_doc_name = 'BILLS-117hr1251ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_hash_vectorized_transformation(A_doc, doc_hash_vectorizer)
B_doc_vectorized = document_hash_vectorized_transformation(B_doc, doc_hash_vectorizer)

A_section_doc_vectorized = section_doc_hash_vectorized_transformation(A_section_doc, sec_hash_vectorizer)
B_section_doc_vectorized = section_doc_hash_vectorized_transformation(B_section_doc, sec_hash_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr1251eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr1251ih",
#           "DOCUMENT SIMILARITY SCORE: 0.9447072707453308",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000027
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.09738982245370617
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.03208561247205913
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.007452007585104285
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.00516984027120511
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.004393747751637492
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.975781843706264
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.07405263227639576
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.024025371481155217
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.017120409880850077
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.010908350586721474
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.010082061677848727
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.004376042853222113
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.0033147491729730826
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0015836409799774864
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 1.000000000000004
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.11599401102005368
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.019292105854557547
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.00615294330296219
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 4",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000018
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0743522395644916
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.03083486710009995
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.009720610692053948
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.008406998376235665
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.006188511018768721
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.005739170359584828
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.004069279168658188
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 5",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.7629116151662789
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.056800801128463266
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.049354615114865885
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.04370022156068469
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.02989198343398656
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.025057132754026903
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.024592311972712264
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.023987636227163035
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.008075585892707385
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.005787238229649604
#           },
#           "ORIGINAL SENTENCE ID: 6",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000022
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.047766703935030026
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.03669067905720271
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.036263837839699296
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.030045478204725872
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.02427118401632274
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.019292105854557547
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.017189676825424646
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.008406998376235665
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.007452007585104285
#           },
#           "ORIGINAL SENTENCE ID: 7",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.9621491137225845
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0659171924820292
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.046720438130403504
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0384937863586418
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.010712584819344081
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.005613461503844496
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.001800687039152242
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 8",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 1.000000000000001
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.11599401102005368
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.05955454531316781
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.02427118401632274
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.009720610692053948
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.00516984027120511
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0038704748013010776
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0018410119451096885
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0015900481847552657
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 9",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999933
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.06739335381935305
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.05955454531316781
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.051335243386719076
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.030045478204725872
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.010122852383929784
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.006188511018768721
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 10",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000004
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.09738982245370617
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.03669067905720271
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.010801819611755938
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0077069145085809304
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.004069279168658188
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.003328160215631574
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1251ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 8

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr1257eh'
B_doc_name = 'BILLS-117hr1257rfs'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_hash_vectorized_transformation(A_doc, doc_hash_vectorizer)
B_doc_vectorized = document_hash_vectorized_transformation(B_doc, doc_hash_vectorizer)

A_section_doc_vectorized = section_doc_hash_vectorized_transformation(A_section_doc, sec_hash_vectorizer)
B_section_doc_vectorized = section_doc_hash_vectorized_transformation(B_section_doc, sec_hash_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr1257eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr1257rfs",
#           "DOCUMENT SIMILARITY SCORE: 1.000000000000042",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1257rfs",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1257rfs",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1257rfs",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1257rfs",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000018
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1257rfs",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0068879933242967485
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1257rfs",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1257rfs",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000004
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1257rfs",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0068879933242967485
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1257rfs",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 9

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr1195eh'
B_doc_name = 'BILLS-117hr1195rh'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_hash_vectorized_transformation(A_doc, doc_hash_vectorizer)
B_doc_vectorized = document_hash_vectorized_transformation(B_doc, doc_hash_vectorizer)

A_section_doc_vectorized = section_doc_hash_vectorized_transformation(A_section_doc, sec_hash_vectorizer)
B_section_doc_vectorized = section_doc_hash_vectorized_transformation(B_section_doc, sec_hash_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr1195eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr1195rh",
#           "DOCUMENT SIMILARITY SCORE: 0.9835438921537075",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.16805349924838137
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.03724711252952215
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.033633639699815615
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000004
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.12565388414768014
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.033633639699815615
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0028218879214653805
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.9697720309975824
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.16540561450194455
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.12307945235349514
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.12031536905592868
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.05647831063847004
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.03509484917006726
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0017777672428919743
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 4",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.9914367969987856
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.11432245256353102
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0570966690972205
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.04187089067129492
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.01541267072458278
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.008432290716936044
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 5",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.9761296015870492
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.12411243857091478
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.11296444775037574
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.02239055377599458
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.015360450318182475
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.010208249115625356
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0027740558477878704
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 6",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.8876253645985963
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.12585634889349645
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.026743109337025124
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.008508312214487779
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.006944611899489514
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 7",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999714
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.042086907018159675
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.015625305184721997
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.00188679245283016
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0016371019870343839
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 8",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999992
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.16805349924838137
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.12565388414768014
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.11787134306647595
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.03263956049169339
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.02277662625494185
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.015492186320548744
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1195rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0016371019870343839
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 10

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr1262eh'
B_doc_name = 'BILLS-117hr1262ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_hash_vectorized_transformation(A_doc, doc_hash_vectorizer)
B_doc_vectorized = document_hash_vectorized_transformation(B_doc, doc_hash_vectorizer)

A_section_doc_vectorized = section_doc_hash_vectorized_transformation(A_section_doc, sec_hash_vectorizer)
B_section_doc_vectorized = section_doc_hash_vectorized_transformation(B_section_doc, sec_hash_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr1262eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr1262ih",
#           "DOCUMENT SIMILARITY SCORE: 0.9463086319471281",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1262ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1262ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1262ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.9449850221132888
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1262ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 11

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr1280eh'
B_doc_name = 'BILLS-117hr1280ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_hash_vectorized_transformation(A_doc, doc_hash_vectorizer)
B_doc_vectorized = document_hash_vectorized_transformation(B_doc, doc_hash_vectorizer)

A_section_doc_vectorized = section_doc_hash_vectorized_transformation(A_section_doc, sec_hash_vectorizer)
B_section_doc_vectorized = section_doc_hash_vectorized_transformation(B_section_doc, sec_hash_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr1280eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr1280ih",
#           "DOCUMENT SIMILARITY SCORE: 0.9998983537453022",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000004
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 45,
#                "SENTENCE SIMILARITY SCORE": 0.07596714068284574
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.05838949433949799
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 58,
#                "SENTENCE SIMILARITY SCORE": 0.05793153045042203
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 57,
#                "SENTENCE SIMILARITY SCORE": 0.05626552461314216
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 24,
#                "SENTENCE SIMILARITY SCORE": 0.05435766099940251
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 59,
#                "SENTENCE SIMILARITY SCORE": 0.051108461111459176
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 42,
#                "SENTENCE SIMILARITY SCORE": 0.050566785412132984
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 28,
#                "SENTENCE SIMILARITY SCORE": 0.04537071877363369
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 37,
#                "SENTENCE SIMILARITY SCORE": 0.027770781737425632
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.02414902461795395
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 60,
#                "SENTENCE SIMILARITY SCORE": 0.023217303855594028
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 52,
#                "SENTENCE SIMILARITY SCORE": 0.022442180669011696
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 38,
#                "SENTENCE SIMILARITY SCORE": 0.021671826625387008
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 41,
#                "SENTENCE SIMILARITY SCORE": 0.02096109040751584
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.018893635753098444
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 32,
#                "SENTENCE SIMILARITY SCORE": 0.01376253579917086
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.013157894736842144
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.012649300381602316
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 40,
#                "SENTENCE SIMILARITY SCORE": 0.011606691503578397
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.009693545640575795
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.009240090568115589
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 29,
#                "SENTENCE SIMILARITY SCORE": 0.008960595060618427
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 43,
#                "SENTENCE SIMILARITY SCORE": 0.00891998972946383
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.008525514428779602
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.008502245654621604
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 46,
#                "SENTENCE SIMILARITY SCORE": 0.006834195672924785
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 30,
#                "SENTENCE SIMILARITY SCORE": 0.006697734347113461
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 34,
#                "SENTENCE SIMILARITY SCORE": 0.006556222093716366
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.004633952138555926
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 47,
#                "SENTENCE SIMILARITY SCORE": 0.004473100260553208
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.0043808973601410835
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 39,
#                "SENTENCE SIMILARITY SCORE": 0.0035811253549461746
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.003395585738539895
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 19,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 20,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 21,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 22,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 23,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 25,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 26,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 27,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 31,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 33,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 35,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 36,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 44,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 48,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 49,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 50,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 55,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 56,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 61,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 62,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 63,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 53,
#                "SENTENCE SIMILARITY SCORE": -0.001064622886924647
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 54,
#                "SENTENCE SIMILARITY SCORE": -0.0012538438294889354
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 51,
#                "SENTENCE SIMILARITY SCORE": -0.009946433500242853
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 1.000000000000003
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 32,
#                "SENTENCE SIMILARITY SCORE": 0.24883552630436184
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 44,
#                "SENTENCE SIMILARITY SCORE": 0.21537801975339557
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 61,
#                "SENTENCE SIMILARITY SCORE": 0.20528906550577108
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 63,
#                "SENTENCE SIMILARITY SCORE": 0.1774193548387089
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 38,
#                "SENTENCE SIMILARITY SCORE": 0.14990512333965753
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.14521525964828122
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.11187775516489251
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.10624807766618809
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 25,
#                "SENTENCE SIMILARITY SCORE": 0.1016930689619022
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.09088525484651559
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 58,
#                "SENTENCE SIMILARITY SCORE": 0.08792066372506387
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 53,
#                "SENTENCE SIMILARITY SCORE": 0.08678393662124402
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 41,
#                "SENTENCE SIMILARITY SCORE": 0.07505422694304009
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.05838981008115361
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 59,
#                "SENTENCE SIMILARITY SCORE": 0.05311552550293267
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.05285729228212323
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 40,
#                "SENTENCE SIMILARITY SCORE": 0.04623956131264266
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 42,
#                "SENTENCE SIMILARITY SCORE": 0.03874068237219838
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 46,
#                "SENTENCE SIMILARITY SCORE": 0.033044193414965846
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 19,
#                "SENTENCE SIMILARITY SCORE": 0.024216261784420132
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 39,
#                "SENTENCE SIMILARITY SCORE": 0.024143716102701464
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.020843946540514913
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 47,
#                "SENTENCE SIMILARITY SCORE": 0.01919104305334105
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 54,
#                "SENTENCE SIMILARITY SCORE": 0.01690666841052811
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 29,
#                "SENTENCE SIMILARITY SCORE": 0.01647593285339506
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 51,
#                "SENTENCE SIMILARITY SCORE": 0.012192402355136318
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.010694169706699674
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 49,
#                "SENTENCE SIMILARITY SCORE": 0.010558930172709275
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 22,
#                "SENTENCE SIMILARITY SCORE": 0.009955054836263954
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.009379896818969577
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 43,
#                "SENTENCE SIMILARITY SCORE": 0.00911181746558127
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 36,
#                "SENTENCE SIMILARITY SCORE": 0.009103750339196063
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 60,
#                "SENTENCE SIMILARITY SCORE": 0.007114980213811024
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.006987488529985554
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 21,
#                "SENTENCE SIMILARITY SCORE": 0.004876960942054531
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 37,
#                "SENTENCE SIMILARITY SCORE": 0.004863086202867128
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 30,
#                "SENTENCE SIMILARITY SCORE": 0.00410506298694048
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.004032258064516113
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.003395585738539895
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.0032923249230956595
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 34,
#                "SENTENCE SIMILARITY SCORE": 0.0026788864468948407
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.0019381992520196964
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 20,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 23,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 24,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 26,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 27,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 28,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 31,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 33,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 35,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 45,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 48,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 50,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 52,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 55,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 56,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 57,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 62,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 1.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 58,
#                "SENTENCE SIMILARITY SCORE": 0.13758738481975194
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 61,
#                "SENTENCE SIMILARITY SCORE": 0.05892556509887897
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 40,
#                "SENTENCE SIMILARITY SCORE": 0.05513178464199721
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0538468618963304
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 44,
#                "SENTENCE SIMILARITY SCORE": 0.042257712736425875
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 41,
#                "SENTENCE SIMILARITY SCORE": 0.04192218081503155
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 39,
#                "SENTENCE SIMILARITY SCORE": 0.03402069087198856
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 32,
#                "SENTENCE SIMILARITY SCORE": 0.0326860225230307
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.032308533487562
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 38,
#                "SENTENCE SIMILARITY SCORE": 0.02941176470588228
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 43,
#                "SENTENCE SIMILARITY SCORE": 0.025892747964693538
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.02551551815399146
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 36,
#                "SENTENCE SIMILARITY SCORE": 0.02351802170958992
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.022011272658140582
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 53,
#                "SENTENCE SIMILARITY SCORE": 0.020227834851568233
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 60,
#                "SENTENCE SIMILARITY SCORE": 0.018380365552345217
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.01676003807884971
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 25,
#                "SENTENCE SIMILARITY SCORE": 0.015762425689094903
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.013872841640446724
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.013157894736842144
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.009208868358546977
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 46,
#                "SENTENCE SIMILARITY SCORE": 0.007213873210309474
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 47,
#                "SENTENCE SIMILARITY SCORE": 0.0070824087458758915
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 19,
#                "SENTENCE SIMILARITY SCORE": 0.006255867627641892
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.004032258064516113
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 20,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 21,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 22,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 23,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 24,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 26,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 27,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 28,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 29,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 30,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 31,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 33,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 34,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 35,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 37,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 42,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 45,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 48,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 49,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 50,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 51,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 52,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 54,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 55,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 56,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 57,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 59,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 62,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 63,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 4",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999988
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 42,
#                "SENTENCE SIMILARITY SCORE": 0.0919722515590068
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 61,
#                "SENTENCE SIMILARITY SCORE": 0.06768974434224134
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 58,
#                "SENTENCE SIMILARITY SCORE": 0.06020997208638129
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0538468618963304
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 41,
#                "SENTENCE SIMILARITY SCORE": 0.04514755761479992
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 63,
#                "SENTENCE SIMILARITY SCORE": 0.04307748951706432
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 43,
#                "SENTENCE SIMILARITY SCORE": 0.04055980287334816
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.03943349785762825
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 44,
#                "SENTENCE SIMILARITY SCORE": 0.03640712354837002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 40,
#                "SENTENCE SIMILARITY SCORE": 0.03562408312459025
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 39,
#                "SENTENCE SIMILARITY SCORE": 0.0341956056026987
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.033434616134778536
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 25,
#                "SENTENCE SIMILARITY SCORE": 0.03017803232824405
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 38,
#                "SENTENCE SIMILARITY SCORE": 0.029562983001906813
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.0290909615464844
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 32,
#                "SENTENCE SIMILARITY SCORE": 0.028160635851807666
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 19,
#                "SENTENCE SIMILARITY SCORE": 0.02694870721498857
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.022124441901060225
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 60,
#                "SENTENCE SIMILARITY SCORE": 0.021114133450692303
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.020843946540514913
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 36,
#                "SENTENCE SIMILARITY SCORE": 0.02026194667313902
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.018893635753098444
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 53,
#                "SENTENCE SIMILARITY SCORE": 0.01887956078171234
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 46,
#                "SENTENCE SIMILARITY SCORE": 0.016573629205042
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 27,
#                "SENTENCE SIMILARITY SCORE": 0.014898661282996276
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.014655259544013755
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 31,
#                "SENTENCE SIMILARITY SCORE": 0.013357762447546218
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.011952143806764742
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.009626404861963297
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 49,
#                "SENTENCE SIMILARITY SCORE": 0.007833565732564052
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 47,
#                "SENTENCE SIMILARITY SCORE": 0.006101847770120668
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 21,
#                "SENTENCE SIMILARITY SCORE": 0.005427253541292582
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 54,
#                "SENTENCE SIMILARITY SCORE": 0.001710394073326766
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 20,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 22,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 23,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 24,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 26,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 29,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 30,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 33,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 34,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 35,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 37,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 45,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 48,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 50,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 51,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 52,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 55,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 56,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 57,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 59,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 62,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 28,
#                "SENTENCE SIMILARITY SCORE": -0.006876791960130479
#           },
#           "ORIGINAL SENTENCE ID: 5",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999962
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.10551922850953335
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 38,
#                "SENTENCE SIMILARITY SCORE": 0.10452760834211207
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 63,
#                "SENTENCE SIMILARITY SCORE": 0.1001564538114422
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 40,
#                "SENTENCE SIMILARITY SCORE": 0.09974871817876133
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 39,
#                "SENTENCE SIMILARITY SCORE": 0.0989242767276873
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.09264498167841688
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 59,
#                "SENTENCE SIMILARITY SCORE": 0.09139251265108553
#           },
# ...
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 33,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 35,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 36,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 38,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 39,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 40,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 42,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 43,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 44,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 45,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 46,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 47,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 48,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 49,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 50,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 51,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 52,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 53,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 54,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 55,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 56,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 57,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 58,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 59,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 61,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 63,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 63",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 63,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000007
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.1774193548387089
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 32,
#                "SENTENCE SIMILARITY SCORE": 0.13074409009212276
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 44,
#                "SENTENCE SIMILARITY SCORE": 0.11832159566199243
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.1001564538114422
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.09185586535436924
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.07491334485841229
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 25,
#                "SENTENCE SIMILARITY SCORE": 0.06304970275637961
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.05939441718716436
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 38,
#                "SENTENCE SIMILARITY SCORE": 0.05882352941176456
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 53,
#                "SENTENCE SIMILARITY SCORE": 0.04854680364376376
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.04402254531628116
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.04307748951706432
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0402240913892393
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.030042088406305404
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 19,
#                "SENTENCE SIMILARITY SCORE": 0.025023470510567566
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 51,
#                "SENTENCE SIMILARITY SCORE": 0.01889822365046136
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 34,
#                "SENTENCE SIMILARITY SCORE": 0.012456821978061056
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 49,
#                "SENTENCE SIMILARITY SCORE": 0.010910894511799626
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 60,
#                "SENTENCE SIMILARITY SCORE": 0.007352146220938085
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 39,
#                "SENTENCE SIMILARITY SCORE": 0.00680413817439771
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.005415303610738824
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 59,
#                "SENTENCE SIMILARITY SCORE": 0.004222003309207484
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.00368354734341879
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 46,
#                "SENTENCE SIMILARITY SCORE": 0.002885549284123789
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 54,
#                "SENTENCE SIMILARITY SCORE": 0.0023823032760289693
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 20,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 21,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 22,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 23,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 24,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 26,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 27,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 28,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 29,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 30,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 31,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 33,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 35,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 36,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 37,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 40,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 41,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 42,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 43,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 45,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 47,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 48,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 50,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 52,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 55,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 56,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 57,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 58,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 61,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1280ih",
#                "MATCHED SENTENCE ID": 62,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 12

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr1314eh'
B_doc_name = 'BILLS-117hr1314ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_hash_vectorized_transformation(A_doc, doc_hash_vectorizer)
B_doc_vectorized = document_hash_vectorized_transformation(B_doc, doc_hash_vectorizer)

A_section_doc_vectorized = section_doc_hash_vectorized_transformation(A_section_doc, sec_hash_vectorizer)
B_section_doc_vectorized = section_doc_hash_vectorized_transformation(B_section_doc, sec_hash_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr1314eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr1314ih",
#           "DOCUMENT SIMILARITY SCORE: 0.9999999999999992",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1314ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000009
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1314ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1314ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000013
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1314ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 13

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr1318enr'
B_doc_name = 'BILLS-117hr1318eh'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_hash_vectorized_transformation(A_doc, doc_hash_vectorizer)
B_doc_vectorized = document_hash_vectorized_transformation(B_doc, doc_hash_vectorizer)

A_section_doc_vectorized = section_doc_hash_vectorized_transformation(A_section_doc, sec_hash_vectorizer)
B_section_doc_vectorized = section_doc_hash_vectorized_transformation(B_section_doc, sec_hash_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr1318enr",
#           "MATCHED DOCUMENT ID: BILLS-117hr1318eh",
#           "DOCUMENT SIMILARITY SCORE: 0.9999999999999976",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1318eh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1318eh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1318eh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1318eh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1318eh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000033
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1318eh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.017876550691212644
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1318eh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.014260554153163735
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1318eh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1318eh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999996
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1318eh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.8037219602942869
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1318eh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.014260554153163735
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1318eh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 4",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1318eh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999953
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1318eh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.8037219602942869
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1318eh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.017876550691212644
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1318eh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 14

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr1324eh'
B_doc_name = 'BILLS-117hr1324ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_hash_vectorized_transformation(A_doc, doc_hash_vectorizer)
B_doc_vectorized = document_hash_vectorized_transformation(B_doc, doc_hash_vectorizer)

A_section_doc_vectorized = section_doc_hash_vectorized_transformation(A_section_doc, sec_hash_vectorizer)
B_section_doc_vectorized = section_doc_hash_vectorized_transformation(B_section_doc, sec_hash_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr1324eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr1324ih",
#           "DOCUMENT SIMILARITY SCORE: 0.998017598788533",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1324ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1324ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.011348442494136541
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1324ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0058617009654030276
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1324ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.9980838041641086
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1324ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.9863799000090779
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1324ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.011351549528416301
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1324ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.9979550528109745
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1324ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.9863980434438274
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1324ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.005863413661119693
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 15

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr1333eh'
B_doc_name = 'BILLS-117hr1333ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_hash_vectorized_transformation(A_doc, doc_hash_vectorizer)
B_doc_vectorized = document_hash_vectorized_transformation(B_doc, doc_hash_vectorizer)

A_section_doc_vectorized = section_doc_hash_vectorized_transformation(A_section_doc, sec_hash_vectorizer)
B_section_doc_vectorized = section_doc_hash_vectorized_transformation(B_section_doc, sec_hash_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr1333eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr1333ih",
#           "DOCUMENT SIMILARITY SCORE: 0.978476771957055",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1333ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1333ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1333ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1333ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1333ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.6685972735299742
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1333ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.02692800994742402
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1333ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.023989630887044963
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1333ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1333ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999991
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1333ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.09320756419328448
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1333ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.03306187995047289
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1333ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 4",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1333ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.9799115984776903
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1333ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.09184565126780411
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1333ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.02934991133120661
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1333ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 16

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr1392eh'
B_doc_name = 'BILLS-117hr1392ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_hash_vectorized_transformation(A_doc, doc_hash_vectorizer)
B_doc_vectorized = document_hash_vectorized_transformation(B_doc, doc_hash_vectorizer)

A_section_doc_vectorized = section_doc_hash_vectorized_transformation(A_section_doc, sec_hash_vectorizer)
B_section_doc_vectorized = section_doc_hash_vectorized_transformation(B_section_doc, sec_hash_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr1392eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr1392ih",
#           "DOCUMENT SIMILARITY SCORE: 0.9306825354576475",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.34838623009816344
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.008331959251969678
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.9168414353255218
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.24358895746130765
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.17561474657281906
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.09120472676168863
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.03052073092214648
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 4",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.25272893701169
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.22433169838739675
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.1875796949916863
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.013838262554683789
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 5",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.9512940947593187
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.25273686578981236
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.25049582622766103
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.24078935253883596
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.006682053103602974
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 6",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.9708876226817638
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.23369705528226187
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.21959593144944534
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.09355257884705434
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.004552137172453762
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 7",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.00647225466348122
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1392ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 17

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr1602eh'
B_doc_name = 'BILLS-117hr1602ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_hash_vectorized_transformation(A_doc, doc_hash_vectorizer)
B_doc_vectorized = document_hash_vectorized_transformation(B_doc, doc_hash_vectorizer)

A_section_doc_vectorized = section_doc_hash_vectorized_transformation(A_section_doc, sec_hash_vectorizer)
B_section_doc_vectorized = section_doc_hash_vectorized_transformation(B_section_doc, sec_hash_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr1602eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr1602ih",
#           "DOCUMENT SIMILARITY SCORE: 0.9973812893999008",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1602ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1602ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1602ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.9973515659015918
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1602ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 18

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr1651enr'
B_doc_name = 'BILLS-117hr1651ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_hash_vectorized_transformation(A_doc, doc_hash_vectorizer)
B_doc_vectorized = document_hash_vectorized_transformation(B_doc, doc_hash_vectorizer)

A_section_doc_vectorized = section_doc_hash_vectorized_transformation(A_section_doc, sec_hash_vectorizer)
B_section_doc_vectorized = section_doc_hash_vectorized_transformation(B_section_doc, sec_hash_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr1651enr",
#           "MATCHED DOCUMENT ID: BILLS-117hr1651ih",
#           "DOCUMENT SIMILARITY SCORE: 0.7402106774910214",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1651ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1651ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.18257418583505552
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1651ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.8699075413138943
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1651ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.21535276082326638
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1651ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1651ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 19

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr1711eh'
B_doc_name = 'BILLS-117hr1711ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_hash_vectorized_transformation(A_doc, doc_hash_vectorizer)
B_doc_vectorized = document_hash_vectorized_transformation(B_doc, doc_hash_vectorizer)

A_section_doc_vectorized = section_doc_hash_vectorized_transformation(A_section_doc, sec_hash_vectorizer)
B_section_doc_vectorized = section_doc_hash_vectorized_transformation(B_section_doc, sec_hash_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr1711eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr1711ih",
#           "DOCUMENT SIMILARITY SCORE: 0.9999999999999994",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1711ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1711ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1711ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1711ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1711ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999881
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1711ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.015737302291853363
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1711ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1711ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1711ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999999
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1711ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.015737302291853363
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1711ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1711ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 4",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1711ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 1.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1711ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1711ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1711ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 20

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr1833eh'
B_doc_name = 'BILLS-117hr1833ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_hash_vectorized_transformation(A_doc, doc_hash_vectorizer)
B_doc_vectorized = document_hash_vectorized_transformation(B_doc, doc_hash_vectorizer)

A_section_doc_vectorized = section_doc_hash_vectorized_transformation(A_section_doc, sec_hash_vectorizer)
B_section_doc_vectorized = section_doc_hash_vectorized_transformation(B_section_doc, sec_hash_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr1833eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr1833ih",
#           "DOCUMENT SIMILARITY SCORE: 0.7785835671892932",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1833ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000007
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1833ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.013819749820569537
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1833ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.7732879190347287
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1833ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.009166984970282082
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 21

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr2008eh'
B_doc_name = 'BILLS-117hr2008ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_hash_vectorized_transformation(A_doc, doc_hash_vectorizer)
B_doc_vectorized = document_hash_vectorized_transformation(B_doc, doc_hash_vectorizer)

A_section_doc_vectorized = section_doc_hash_vectorized_transformation(A_section_doc, sec_hash_vectorizer)
B_section_doc_vectorized = section_doc_hash_vectorized_transformation(B_section_doc, sec_hash_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr2008eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr2008ih",
#           "DOCUMENT SIMILARITY SCORE: 1.0000000000000002",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2008ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000007
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2008ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2008ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 1.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2008ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 22

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr2016rh'
B_doc_name = 'BILLS-117hr2016ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_hash_vectorized_transformation(A_doc, doc_hash_vectorizer)
B_doc_vectorized = document_hash_vectorized_transformation(B_doc, doc_hash_vectorizer)

A_section_doc_vectorized = section_doc_hash_vectorized_transformation(A_section_doc, sec_hash_vectorizer)
B_section_doc_vectorized = section_doc_hash_vectorized_transformation(B_section_doc, sec_hash_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr2016rh",
#           "MATCHED DOCUMENT ID: BILLS-117hr2016ih",
#           "DOCUMENT SIMILARITY SCORE: 0.9999999999999982",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2016ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2016ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2016ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2016ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000009
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2016ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.9297209228460309
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2016ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2016ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999968
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2016ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.9297209228460309
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2016ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 23

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr2027eh'
B_doc_name = 'BILLS-117hr2027ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_hash_vectorized_transformation(A_doc, doc_hash_vectorizer)
B_doc_vectorized = document_hash_vectorized_transformation(B_doc, doc_hash_vectorizer)

A_section_doc_vectorized = section_doc_hash_vectorized_transformation(A_section_doc, sec_hash_vectorizer)
B_section_doc_vectorized = section_doc_hash_vectorized_transformation(B_section_doc, sec_hash_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr2027eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr2027ih",
#           "DOCUMENT SIMILARITY SCORE: 1.0000000000000022",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000007
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000009
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.12103297960810712
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.11039307767412175
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.07926038473889131
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000004
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.23677431375616606
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.1883088613760039
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.07926038473889131
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 4",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000027
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.3195435601117965
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.1883088613760039
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.12103297960810712
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0036454184655641073
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 5",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999688
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.3195435601117965
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.23677431375616606
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.11039307767412175
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 6",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000069
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0036454184655641073
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2027ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 24

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr2062eh'
B_doc_name = 'BILLS-117hr2062rfs'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_hash_vectorized_transformation(A_doc, doc_hash_vectorizer)
B_doc_vectorized = document_hash_vectorized_transformation(B_doc, doc_hash_vectorizer)

A_section_doc_vectorized = section_doc_hash_vectorized_transformation(A_section_doc, sec_hash_vectorizer)
B_section_doc_vectorized = section_doc_hash_vectorized_transformation(B_section_doc, sec_hash_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr2062eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr2062rfs",
#           "DOCUMENT SIMILARITY SCORE: 1.0000000000000029",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000007
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999992
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.057133932912041004
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.005604748111903664
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999999
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.10508138749854684
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.09764582085806328
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.03791171164674091
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 4",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 1.000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.10508138749854684
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.011799872090079808
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.011453468879067513
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 5",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 1.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.12771624703386739
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.04510353985062128
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.03791171164674091
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.011453468879067513
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 6",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.999999999999998
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.04646766902382145
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.04510353985062128
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.005604748111903664
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 7",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 1.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.12771624703386739
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.09764582085806328
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.057133932912041004
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.04646766902382145
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.011799872090079808
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2062rfs",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 25

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr1573eh'
B_doc_name = 'BILLS-117hr1573ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_hash_vectorized_transformation(A_doc, doc_hash_vectorizer)
B_doc_vectorized = document_hash_vectorized_transformation(B_doc, doc_hash_vectorizer)

A_section_doc_vectorized = section_doc_hash_vectorized_transformation(A_section_doc, sec_hash_vectorizer)
B_section_doc_vectorized = section_doc_hash_vectorized_transformation(B_section_doc, sec_hash_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr1573eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr1573ih",
#           "DOCUMENT SIMILARITY SCORE: 0.9419354339119264",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1573ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1573ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1573ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.9409949123808377
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr1573ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 26

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr2332eh'
B_doc_name = 'BILLS-117hr2332ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_hash_vectorized_transformation(A_doc, doc_hash_vectorizer)
B_doc_vectorized = document_hash_vectorized_transformation(B_doc, doc_hash_vectorizer)

A_section_doc_vectorized = section_doc_hash_vectorized_transformation(A_section_doc, sec_hash_vectorizer)
B_section_doc_vectorized = section_doc_hash_vectorized_transformation(B_section_doc, sec_hash_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr2332eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr2332ih",
#           "DOCUMENT SIMILARITY SCORE: 0.7540527991706186",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2332ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000007
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2332ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2332ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2332ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.7435701586071991
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2332ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.5979984834208307
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2332ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2332ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.7551647462657463
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2332ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.6355151794872143
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2332ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 27

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr2467ih'
B_doc_name = 'BILLS-117hr2467rh'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_hash_vectorized_transformation(A_doc, doc_hash_vectorizer)
B_doc_vectorized = document_hash_vectorized_transformation(B_doc, doc_hash_vectorizer)

A_section_doc_vectorized = section_doc_hash_vectorized_transformation(A_section_doc, sec_hash_vectorizer)
B_section_doc_vectorized = section_doc_hash_vectorized_transformation(B_section_doc, sec_hash_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr2467ih",
#           "MATCHED DOCUMENT ID: BILLS-117hr2467rh",
#           "DOCUMENT SIMILARITY SCORE: 1.0000000000000069",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999998
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.1525862131963526
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.0917370968279732
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.05347371793934068
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.053092863656040976
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.052494422763856255
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.03725175123463821
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.03482843300043587
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.032086901194021696
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.02966954145484635
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.019318434087695534
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.006339088492564036
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0030869785274811458
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000009
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.3413166365787378
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.2262615269800845
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.12685850902643783
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.11736302082741322
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.11339233730204498
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.09197333051238239
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.09056802835627115
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.08824259199017931
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.06531423682560052
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.06465918465613468
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.056658644724578724
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.05557490937138827
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.04347374844298194
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.034659650723028956
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.008263867040752475
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.007630587009109039
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.006339088492564036
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999996
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.23906314692954578
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.1776263325003779
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.13150828197805672
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.1241616472883346
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.10544454672463709
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.07738533610592549
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.07529599410802411
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.06465918465613468
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.054432866812024125
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.053092863656040976
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.04887218045112793
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.04068371145415187
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.02569858290856298
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.02439928026172454
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.017189401703741676
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.005428532875046294
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 4",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 1.000000000000005
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.23906314692954578
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.10579345423781177
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.07854213071089998
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.073139682979523
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.05162257329196715
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.046348977465932216
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.044298988794094246
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.034659650723028956
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.032086901194021696
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.030803248065723137
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.028649002839569365
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.0267997331188667
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.02675106566194378
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.022075539284417474
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.016731862035256388
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.015945495774498008
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 5",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999982
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.3930688794998818
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.10544454672463709
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.07854213071089998
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.04777098589806143
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.04347374844298194
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.03795476723787696
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.03794180397790322
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.03647863240984383
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.034645607897814505
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.033097865951293146
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.030548913705519126
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.025846804765599207
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.02146549701180106
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.020663971700844504
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.020447589071058245
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.019318434087695534
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 6",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000004
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.3930688794998818
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.09197333051238239
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.08138243900010042
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.06622661785325214
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.06552646094745043
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.04966996338993911
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.04595196996879332
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.043115565817939676
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0310075794084383
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.02929374625741897
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.028649002839569365
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.027036903521793793
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.02439928026172454
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.020492262216511854
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.007024942431930339
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 7",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 1.000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.9808725507209322
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.08949915586306247
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.07529599410802411
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.073139682979523
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.07077495678450639
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.06875511821675968
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.06615733247144183
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.061386420107714355
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.05557490937138827
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.05309543241765277
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.03647863240984383
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0310075794084383
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.016097191347738137
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.014863624810934584
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0030869785274811458
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 8",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000213
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.9808725507209322
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.09124442905174786
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.07215509979608249
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.07009587348144845
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.06258348249484226
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.056658644724578724
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.054432866812024125
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.054130816871803024
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.05162257329196715
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.0492885063654462
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.030548913705519126
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.016411093710295956
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.007024942431930339
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 9",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999951
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.3413166365787378
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.20770879006643836
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.14494698828703237
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.13150828197805672
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.1233360741654353
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.12288478807785595
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.12020982907268335
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.11036851024495753
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.09203182749813993
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.09124442905174786
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.08949915586306247
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.08138243900010042
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.05347371793934068
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.044298988794094246
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.03795476723787696
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.023406626300543982
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 10",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000004
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.1776263325003779
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.12020982907268335
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.10579345423781177
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.07433989681635121
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.06615733247144183
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.06531423682560052
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.06490459625752701
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0492885063654462
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.04891159880445174
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.04777098589806143
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.03482843300043587
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.027221905496094812
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.01597446127661744
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.01592147784284323
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 11",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000004
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.1358749645889608
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.1233360741654353
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.11736302082741322
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.06312327194758417
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.06258348249484226
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.061386420107714355
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.052432238663187226
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.043115565817939676
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.040689422938557956
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.034645607897814505
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.030803248065723137
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.02569858290856298
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.023997312451499688
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.020983967658419287
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.01592147784284323
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 12",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.2262615269800845
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.20770879006643836
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.1358749645889608
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.10098305835736603
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0917370968279732
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.0850289569391772
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.07215509979608249
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.07077495678450639
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.06552646094745043
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.05014734296369116
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.04801581213031016
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.04068371145415187
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.03794180397790322
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.027221905496094812
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.02675106566194378
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.0031891153721560514
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 13",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.12685850902643783
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.12288478807785595
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.0850289569391772
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.07372097807744851
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.04966996338993911
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.04082482904638638
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.040689422938557956
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.02966954145484635
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.01239034875853298
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 14",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000007
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.357830730827001
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.020983967658419287
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.020663971700844504
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.020492262216511854
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.016731862035256388
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.016411093710295956
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.016097191347738137
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.008263867040752475
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.005428532875046294
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.0031891153721560514
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 15",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999984
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.11339233730204498
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.11036851024495753
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.10098305835736603
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.06312327194758417
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.054130816871803024
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.05309543241765277
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.04082482904638638
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.033722257992814295
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.027036903521793793
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.024077170617153865
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.022075539284417474
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.020447589071058245
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.017189401703741676
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.01597446127661744
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 16",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999968
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.14494698828703237
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.1241616472883346
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.09056802835627115
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.07372097807744851
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.06490459625752701
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.052494422763856255
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.05014734296369116
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.03897295484585605
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.02929374625741897
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.025846804765599207
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.024077170617153865
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.023997312451499688
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.021063136593556707
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.015945495774498008
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 17",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 1.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.1525862131963526
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.06622661785325214
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.04891159880445174
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.04887218045112793
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.046348977465932216
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.023406626300543982
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.02146549701180106
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.021063136593556707
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.014863624810934584
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.007630587009109039
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 0.007080199290590272
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 18",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 18,
#                "SENTENCE SIMILARITY SCORE": 1.000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 14,
#                "SENTENCE SIMILARITY SCORE": 0.357830730827001
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.09203182749813993
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.08824259199017931
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.07738533610592549
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 10,
#                "SENTENCE SIMILARITY SCORE": 0.07433989681635121
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.07009587348144845
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.06875511821675968
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 11,
#                "SENTENCE SIMILARITY SCORE": 0.052432238663187226
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 12,
#                "SENTENCE SIMILARITY SCORE": 0.04801581213031016
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.04595196996879332
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 16,
#                "SENTENCE SIMILARITY SCORE": 0.03897295484585605
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.03725175123463821
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 15,
#                "SENTENCE SIMILARITY SCORE": 0.033722257992814295
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.033097865951293146
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0267997331188667
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 13,
#                "SENTENCE SIMILARITY SCORE": 0.01239034875853298
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2467rh",
#                "MATCHED SENTENCE ID": 17,
#                "SENTENCE SIMILARITY SCORE": 0.007080199290590272
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 28

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr2485eh'
B_doc_name = 'BILLS-117hr2485ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_hash_vectorized_transformation(A_doc, doc_hash_vectorizer)
B_doc_vectorized = document_hash_vectorized_transformation(B_doc, doc_hash_vectorizer)

A_section_doc_vectorized = section_doc_hash_vectorized_transformation(A_section_doc, sec_hash_vectorizer)
B_section_doc_vectorized = section_doc_hash_vectorized_transformation(B_section_doc, sec_hash_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr2485eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr2485ih",
#           "DOCUMENT SIMILARITY SCORE: 0.9988266353769495",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000016
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.07787999022746352
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.03120758887514121
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.029051751630007235
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.019617499646764805
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.014293544840260356
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 1.000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.14308904743244277
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.10256737110906933
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.091027023615215
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.021603665263824054
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.014293544840260356
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.004011440898785492
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 4",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.1548480050181605
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.10256737110906933
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.03308187924364813
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.029051751630007235
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.02095687060724288
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 5",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 1.000000000000001
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.1548480050181605
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.091027023615215
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.08798084150831305
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.045284308578239674
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.019617499646764805
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 6",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000007
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.07787999022746352
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.045284308578239674
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.021603665263824054
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.02095687060724288
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.010914915254633091
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.007649875767026304
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 7",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999989
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.14308904743244277
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.08798084150831305
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.03308187924364813
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.03120758887514121
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.010914915254633091
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 8",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.9375
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.007649875767026304
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.004011440898785492
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2485ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 29

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr2523eh'
B_doc_name = 'BILLS-117hr2523ih'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_hash_vectorized_transformation(A_doc, doc_hash_vectorizer)
B_doc_vectorized = document_hash_vectorized_transformation(B_doc, doc_hash_vectorizer)

A_section_doc_vectorized = section_doc_hash_vectorized_transformation(A_section_doc, sec_hash_vectorizer)
B_section_doc_vectorized = section_doc_hash_vectorized_transformation(B_section_doc, sec_hash_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr2523eh",
#           "MATCHED DOCUMENT ID: BILLS-117hr2523ih",
#           "DOCUMENT SIMILARITY SCORE: 0.9824861031052958",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000009
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.9289489127060078
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.08948275789542914
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.08397530991956866
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.07280084611252811
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.04939282078131868
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.04619347813415316
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.03269434021218041
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0035298905920306397
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000016
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.11365668916983604
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.09572176385997488
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0858132251289712
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0513401284519365
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0209731193054953
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 4",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000004
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.8767173115529698
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.2877919418836552
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.20203201479711475
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.09572176385997488
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.08827894254679104
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.07503407933640767
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 5",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.8767173115529698
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.11365668916983604
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.08145632270279292
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.08104249296663037
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.05834143687346179
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.014974191759656046
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 6",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.2933605435603703
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.2877919418836552
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.17763522553300745
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.05834143687346179
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.012941473814440586
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 7",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000007
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.17763522553300745
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.13423434944920826
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.08827894254679104
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.02790161188780156
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0209731193054953
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.014974191759656046
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 8",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000007
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.2933605435603703
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.20203201479711475
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.13423434944920826
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0858132251289712
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.08104249296663037
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.06745004419977774
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 9",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 9,
#                "SENTENCE SIMILARITY SCORE": 1.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.00351450973197209
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 5,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 6,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 7,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr2523ih",
#                "MATCHED SENTENCE ID": 8,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 30

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117hr3007ih'
B_doc_name = 'BILLS-117hr3007rh'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_hash_vectorized_transformation(A_doc, doc_hash_vectorizer)
B_doc_vectorized = document_hash_vectorized_transformation(B_doc, doc_hash_vectorizer)

A_section_doc_vectorized = section_doc_hash_vectorized_transformation(A_section_doc, sec_hash_vectorizer)
B_section_doc_vectorized = section_doc_hash_vectorized_transformation(B_section_doc, sec_hash_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117hr3007ih",
#           "MATCHED DOCUMENT ID: BILLS-117hr3007rh",
#           "DOCUMENT SIMILARITY SCORE: 0.9657708021584301",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr3007rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000007
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr3007rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr3007rh",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.9652103098677537
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117hr3007rh",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 31

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117s658rfh'
B_doc_name = 'BILLS-117s658rs'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_hash_vectorized_transformation(A_doc, doc_hash_vectorizer)
B_doc_vectorized = document_hash_vectorized_transformation(B_doc, doc_hash_vectorizer)

A_section_doc_vectorized = section_doc_hash_vectorized_transformation(A_section_doc, sec_hash_vectorizer)
B_section_doc_vectorized = section_doc_hash_vectorized_transformation(B_section_doc, sec_hash_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117s658rfh",
#           "MATCHED DOCUMENT ID: BILLS-117s658rs",
#           "DOCUMENT SIMILARITY SCORE: 0.9999999999999986",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117s658rs",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117s658rs",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117s658rs",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117s658rs",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117s658rs",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999978
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117s658rs",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.08956174739052739
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117s658rs",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117s658rs",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 3",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117s658rs",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000018
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117s658rs",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.08956174739052739
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117s658rs",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117s658rs",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 4",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117s658rs",
#                "MATCHED SENTENCE ID": 4,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999999
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117s658rs",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117s658rs",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117s658rs",
#                "MATCHED SENTENCE ID": 3,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 32

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117sjres13is'
B_doc_name = 'BILLS-117sjres13es'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_hash_vectorized_transformation(A_doc, doc_hash_vectorizer)
B_doc_vectorized = document_hash_vectorized_transformation(B_doc, doc_hash_vectorizer)

A_section_doc_vectorized = section_doc_hash_vectorized_transformation(A_section_doc, sec_hash_vectorizer)
B_section_doc_vectorized = section_doc_hash_vectorized_transformation(B_section_doc, sec_hash_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117sjres13is",
#           "MATCHED DOCUMENT ID: BILLS-117sjres13es",
#           "DOCUMENT SIMILARITY SCORE: 0.9999999999999996",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117sjres13es",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999996
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 33

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117sres107is'
B_doc_name = 'BILLS-117sres107rs'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_hash_vectorized_transformation(A_doc, doc_hash_vectorizer)
B_doc_vectorized = document_hash_vectorized_transformation(B_doc, doc_hash_vectorizer)

A_section_doc_vectorized = section_doc_hash_vectorized_transformation(A_section_doc, sec_hash_vectorizer)
B_section_doc_vectorized = section_doc_hash_vectorized_transformation(B_section_doc, sec_hash_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117sres107is",
#           "MATCHED DOCUMENT ID: BILLS-117sres107rs",
#           "DOCUMENT SIMILARITY SCORE: 0.9999999999999996",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117sres107rs",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999996
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 34

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117sres120is'
B_doc_name = 'BILLS-117sres120ats'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_hash_vectorized_transformation(A_doc, doc_hash_vectorizer)
B_doc_vectorized = document_hash_vectorized_transformation(B_doc, doc_hash_vectorizer)

A_section_doc_vectorized = section_doc_hash_vectorized_transformation(A_section_doc, sec_hash_vectorizer)
B_section_doc_vectorized = section_doc_hash_vectorized_transformation(B_section_doc, sec_hash_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117sres120is",
#           "MATCHED DOCUMENT ID: BILLS-117sres120ats",
#           "DOCUMENT SIMILARITY SCORE: 0.9999999999999984",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117sres120ats",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999984
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 35

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117sres81ats'
B_doc_name = 'BILLS-117sres81is'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_hash_vectorized_transformation(A_doc, doc_hash_vectorizer)
B_doc_vectorized = document_hash_vectorized_transformation(B_doc, doc_hash_vectorizer)

A_section_doc_vectorized = section_doc_hash_vectorized_transformation(A_section_doc, sec_hash_vectorizer)
B_section_doc_vectorized = section_doc_hash_vectorized_transformation(B_section_doc, sec_hash_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117sres81ats",
#           "MATCHED DOCUMENT ID: BILLS-117sres81is",
#           "DOCUMENT SIMILARITY SCORE: 1.0000000000000007",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117sres81is",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000007
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 36

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117sres37is'
B_doc_name = 'BILLS-117sres37rs'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_hash_vectorized_transformation(A_doc, doc_hash_vectorizer)
B_doc_vectorized = document_hash_vectorized_transformation(B_doc, doc_hash_vectorizer)

A_section_doc_vectorized = section_doc_hash_vectorized_transformation(A_section_doc, sec_hash_vectorizer)
B_section_doc_vectorized = section_doc_hash_vectorized_transformation(B_section_doc, sec_hash_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117sres37is",
#           "MATCHED DOCUMENT ID: BILLS-117sres37rs",
#           "DOCUMENT SIMILARITY SCORE: 0.9874880466425388",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117sres37rs",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.000000000000006
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117sres37rs",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.9579080043578716
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 37

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117sres22is'
B_doc_name = 'BILLS-117sres22rs'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_hash_vectorized_transformation(A_doc, doc_hash_vectorizer)
B_doc_vectorized = document_hash_vectorized_transformation(B_doc, doc_hash_vectorizer)

A_section_doc_vectorized = section_doc_hash_vectorized_transformation(A_section_doc, sec_hash_vectorizer)
B_section_doc_vectorized = section_doc_hash_vectorized_transformation(B_section_doc, sec_hash_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117sres22is",
#           "MATCHED DOCUMENT ID: BILLS-117sres22rs",
#           "DOCUMENT SIMILARITY SCORE: 1.0000000000000089",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117sres22rs",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000089
#           }
#      ]
# ]

# %% [markdown]
# ## Case # 38

# %%
#pick any Document A & any Document B from data lists (at least that have more than 1 section)
A_doc_name = 'BILLS-117s1910es'
B_doc_name = 'BILLS-117s1910is'

A_doc, A_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, A_doc_name+".xml"))
B_doc, B_section_doc = get_document_and_section_from_xml_file(os.path.join(PATH_117_USLM, B_doc_name+".xml"))

# %%
A_doc_vectorized = document_hash_vectorized_transformation(A_doc, doc_hash_vectorizer)
B_doc_vectorized = document_hash_vectorized_transformation(B_doc, doc_hash_vectorizer)

A_section_doc_vectorized = section_doc_hash_vectorized_transformation(A_section_doc, sec_hash_vectorizer)
B_section_doc_vectorized = section_doc_hash_vectorized_transformation(B_section_doc, sec_hash_vectorizer)

# %%
elapsed, doc_sim_score = cosine_pairwise_sim(A_doc_vectorized, B_doc_vectorized)
elapsed, sec_doc_sim_score = cosine_pairwise_sim(A_section_doc_vectorized, B_section_doc_vectorized)

response = create_json_response(A_doc_name, B_doc_name, doc_sim_score, sec_doc_sim_score)
print(response)
# Out:
# [
#      [
#           "ORIGINAL DOCUMENT ID: BILLS-117s1910es",
#           "MATCHED DOCUMENT ID: BILLS-117s1910is",
#           "DOCUMENT SIMILARITY SCORE: 0.9999999999999996",
#           "ORIGINAL SENTENCE ID: 1",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117s1910is",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 1.0000000000000002
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117s1910is",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           },
#           "ORIGINAL SENTENCE ID: 2",
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117s1910is",
#                "MATCHED SENTENCE ID": 2,
#                "SENTENCE SIMILARITY SCORE": 0.9999999999999998
#           },
#           {
#                "MATCHED DOCUMENT ID": "BILLS-117s1910is",
#                "MATCHED SENTENCE ID": 1,
#                "SENTENCE SIMILARITY SCORE": 0.0
#           }
#      ]
# ]
